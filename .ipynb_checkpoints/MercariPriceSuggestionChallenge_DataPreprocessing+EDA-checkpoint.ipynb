# %% [markdown]
# # [Mercari Price Suggestion Challenge](https://www.kaggle.com/c/mercari-price-suggestion-challenge)
# Can you automatically suggest product prices to online sellers?

# %% [markdown]
# # Import packages

# %%
import pandas as pd #data processing
import numpy as np #linear algebra
from scipy import stats
from scipy.cluster.hierarchy import linkage, dendrogram

# %matplotlib inline
import matplotlib.pyplot as plt #commonly used visualization tool
import seaborn as sns #new visualization tool
from string import ascii_letters
from wordcloud import WordCloud

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV #hyper-parameter tuning
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Import data

# %% [markdown]
# set train and test data, split by tab because of the tsv format.

# %%
# %%time
train_df = pd.read_csv("data/train.tsv", delimiter="\t", low_memory= True)
test_df = pd.read_csv("data/test.tsv", delimiter="\t", low_memory= True)
# Out:
# CPU times: user 7.21 s, sys: 765 ms, total: 7.97 s
# Wall time: 7.12 s

# %%
train_df.head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# 1         0  This keyboard is in great condition and works ...
# 2         1  Adorable top with a hint of lace and a key hol...
# 3         1  New with tags. Leather horses. Retail for [rm]...
# 4         0          Complete with certificate of authenticity

# %%
train_df.columns
# Out:
# Index(['train_id', 'name', 'item_condition_id', 'category_name', 'brand_name',
#        'price', 'shipping', 'item_description'],
#       dtype='object')

# %% [markdown]
# ### converting column types

# %%
print(train_df.dtypes)
print("------------")
print(test_df.dtypes)
# Out:
# train_id               int64
# name                  object
# item_condition_id      int64
# category_name         object
# brand_name            object
# price                float64
# shipping               int64
# item_description      object
# dtype: object
# ------------
# test_id               int64
# name                 object
# item_condition_id     int64
# category_name        object
# brand_name           object
# shipping              int64
# item_description     object
# dtype: object

# %%
train_df["item_condition_id"] = train_df["item_condition_id"].astype("int32")
train_df["shipping"] = train_df["shipping"].astype("int8")

test_df["item_condition_id"] = test_df["item_condition_id"].astype("int32")
test_df["shipping"] = test_df["shipping"].astype("int8")

# %%
print(train_df.dtypes)
print("------------")
print(test_df.dtypes)
# Out:
# train_id               int64
# name                  object
# item_condition_id      int32
# category_name         object
# brand_name            object
# price                float64
# shipping                int8
# item_description      object
# dtype: object
# ------------
# test_id               int64
# name                 object
# item_condition_id     int32
# category_name        object
# brand_name           object
# shipping               int8
# item_description     object
# dtype: object

# %% [markdown]
# do a little exploring on discriptive statistics

# %%
print("train_df shape: {}\ntest_df shape: {}".format(train_df.shape, test_df.shape))
# Out:
# train_df shape: (1482535, 8)
# test_df shape: (693359, 7)

# %%
pd.set_option("float_format", "{:f}".format)
train_df.describe()
# Out:
#             train_id  item_condition_id          price       shipping
# count 1482535.000000     1482535.000000 1482535.000000 1482535.000000
# mean   741267.000000           1.907380      26.737516       0.447274
# std    427971.135004           0.903159      38.586066       0.497212
# min         0.000000           1.000000       0.000000       0.000000
# 25%    370633.500000           1.000000      10.000000       0.000000
# 50%    741267.000000           2.000000      17.000000       0.000000
# 75%   1111900.500000           3.000000      29.000000       1.000000
# max   1482534.000000           5.000000    2009.000000       1.000000

# %% [markdown]
# checking individual values

# %%
train_df.apply(lambda x: x.nunique())
# Out:
# train_id             1482535
# name                 1225273
# item_condition_id          5
# category_name           1287
# brand_name              4809
# price                    828
# shipping                   2
# item_description     1281426
# dtype: int64

# %% [markdown]
# # data preprocessing

# %% [markdown]
# ### checking missing values

# %% [markdown]
# found missing values in category_name, brand_name, and item_discription

# %%
print(train_df.isnull().sum()[train_df.isnull().sum() != 0])
print("------------")
print(test_df.isnull().sum()[test_df.isnull().sum() != 0])
# Out:
# category_name         6327
# brand_name          632682
# item_description         4
# dtype: int64
# ------------
# category_name      3058
# brand_name       295525
# dtype: int64

# %% [markdown]
# - Fill products with no brand name with 'NoBrand'
# - Fill products with no category name with 'No/No/No'
# - Fill products with no item descriptions with 'No description yet' (same as the first data)

# %%
train_df["brand_name"] = train_df["brand_name"].fillna("NoBrand")
test_df["brand_name"] = test_df["brand_name"].fillna("NoBrand")

train_df["category_name"] = train_df["category_name"].fillna("No/No/No")
test_df["category_name"] = test_df["category_name"].fillna("No/No/No")

train_df["item_description"] = train_df["item_description"].fillna("No description yet")

# %%
print(train_df.isnull().sum()[train_df.isnull().sum() != 0])
print("------------")
print(test_df.isnull().sum()[test_df.isnull().sum() != 0])
# Out:
# Series([], dtype: int64)
# ------------
# Series([], dtype: int64)

# %% [markdown]
# # feature engineering

# %% [markdown]
# extracting data from category_name, brand_name, and item_discription

# %% [markdown]
# split category_name into:
# - general_category
# - subcategory_1
# - subcategory_2

# %%
split_category_name = train_df["category_name"].str.split("/", n = 2, expand = True)
split_category_name
# Out:
#                          0                    1                    2
# 0                      Men                 Tops             T-shirts
# 1              Electronics  Computers & Tablets   Components & Parts
# 2                    Women       Tops & Blouses               Blouse
# 3                     Home           Home Décor   Home Décor Accents
# 4                    Women              Jewelry            Necklaces
# ...                    ...                  ...                  ...
# 1482530              Women              Dresses             Mid-Calf
# 1482531               Kids          Girls 2T-5T              Dresses
# 1482532  Sports & Outdoors             Exercise  Fitness accessories
# 1482533               Home           Home Décor   Home Décor Accents
# 1482534              Women  Women's Accessories              Wallets
#
# [1482535 rows x 3 columns]

# %%
train_df["general_category"] = split_category_name[0]
train_df["subcategory_1"] = split_category_name[1]
train_df["subcategory_2"] = split_category_name[2]

# %%
split_category_name_2 = test_df["category_name"].str.split("/", n = 2, expand = True)
split_category_name_2
# Out:
#                              0                          1  \
# 0                        Women                    Jewelry
# 1                        Other            Office supplies
# 2       Vintage & Collectibles            Bags and Purses
# 3                        Women                   Sweaters
# 4                        Other                      Books
# ...                        ...                        ...
# 693354                    Home                 Home Décor
# 693355                  Beauty                     Makeup
# 693356             Electronics  Cell Phones & Accessories
# 693357                   Women                   Swimwear
# 693358                   Women             Tops & Blouses
#
#                               2
# 0                         Rings
# 1             Shipping Supplies
# 2                       Handbag
# 3                      Cardigan
# 4       Religion & Spirituality
# ...                         ...
# 693354       Home Décor Accents
# 693355              Makeup Sets
# 693356    Cases, Covers & Skins
# 693357                Cover-Ups
# 693358                 T-Shirts
#
# [693359 rows x 3 columns]

# %%
test_df["general_category"] = split_category_name_2[0]
test_df["subcategory_1"] = split_category_name_2[1]
test_df["subcategory_2"] = split_category_name_2[2]

# %%
#train_df.drop(columns =["category_name"], inplace = True) 

#test_df.drop(columns =["category_name"], inplace = True)

# %% [markdown]
# dealing with item_description
# <br>[Extensive Text Data Feature Engineering](https://www.kaggle.com/shivamb/extensive-text-data-feature-engineering)
# - character length
# - word count
# - word density
# - puncutation count

# %%
train_df["char_count"] = train_df["item_description"].apply(len)
train_df["word_count"] = train_df["item_description"].apply(lambda x: len(x.split()))
train_df["word_density"] = train_df["char_count"] / (train_df["word_count"]+1)

test_df["char_count"] = test_df["item_description"].apply(len)
test_df["word_count"] = test_df["item_description"].apply(lambda x: len(x.split()))
test_df["word_density"] = test_df["char_count"] / (test_df["word_count"]+1)

# %% [markdown]
# [CountVectorizer, TfidfVectorizer, Predict Comments](https://www.kaggle.com/adamschroeder/countvectorizer-tfidfvectorizer-predict-comments)
# - TFIDF

# %%
vectorizer = TfidfVectorizer(min_df=3, max_features=2500, dtype=np.float32, 
                             strip_accents="unicode", analyzer="word", ngram_range=(1, 3), stop_words={"english", "rm", "co"})

# %%
# %%time
description_text = list(train_df["item_description"].values)
tfidf_matrix = vectorizer.fit_transform(description_text)
# Out:
# CPU times: user 4min 41s, sys: 20.7 s, total: 5min 2s
# Wall time: 5min 20s

# %%
tfidf_matrix
# Out:
# <1482535x2500 sparse matrix of type '<class 'numpy.float32'>'
# 	with 33068128 stored elements in Compressed Sparse Row format>

# %%
tfidf_matrix.shape
# Out:
# (1482535, 2500)

# %% [markdown]
# [Using TfidfVectorizer output to create columns in a pandas df](https://www.reddit.com/r/learnpython/comments/7aduzh/using_tfidfvectorizer_output_to_create_columns_in/)

# %% [markdown]
# the learned corpus vocabulary

# %%
vectorizer.vocabulary_
# Out:
# {'no': 1392,
#  'description': 592,
#  'yet': 2462,
#  'no description': 1394,
#  'description yet': 593,
#  'no description yet': 1395,
#  'this': 2162,
#  'is': 1034,
#  'in': 974,
#  'great': 866,
#  'condition': 512,
#  'and': 122,
#  'works': 2432,
#  'like': 1159,
#  'it': 1058,
#  'came': 407,
#  'out': 1534,
#  'of': 1442,
#  'the': 2114,
#  'box': 326,
#  'all': 93,
#  'are': 181,
#  'tested': 2098,
#  'work': 2429,
#  'perfectly': 1593,
#  'lights': 1157,
#  'via': 2314,
#  'app': 173,
#  'on': 1465,
#  'your': 2491,
#  'pc': 1580,
#  'is in': 1042,
#  'in great': 982,
#  'great condition': 867,
#  'condition and': 513,
#  'out of': 1538,
#  'of the': 1448,
#  'the box': 2119,
#  'all of': 102,
#  'on your': 1483,
#  'is in great': 1044,
#  'in great condition': 983,
#  'adorable': 85,
#  'top': 2221,
#  'with': 2392,
#  'lace': 1117,
#  'key': 1101,
#  'hole': 943,
#  'back': 228,
#  'pink': 1617,
#  '1x': 18,
#  'also': 110,
#  'have': 909,
#  '3x': 48,
#  'available': 222,
#  'white': 2367,
#  'top with': 2226,
#  'in the': 997,
#  'the back': 2115,
#  'also have': 111,
#  'available in': 224,
#  'in the back': 998,
#  'new': 1356,
#  'tags': 2073,
#  'leather': 1131,
#  'retail': 1756,
#  'for': 756,
#  'each': 650,
#  'stand': 2008,
#  'about': 67,
#  'foot': 755,
#  'high': 934,
#  'they': 2152,
#  'being': 272,
#  'sold': 1977,
#  'as': 198,
#  'pair': 1563,
#  'any': 167,
#  'questions': 1714,
#  'please': 1627,
#  'ask': 209,
#  'free': 791,
#  'shipping': 1864,
#  'just': 1094,
#  'got': 864,
#  'storage': 2027,
#  'new with': 1379,
#  'with tags': 2408,
#  'for each': 763,
#  'they are': 2153,
#  'sold as': 1978,
#  'any questions': 169,
#  'questions please': 1716,
#  'please ask': 1628,
#  'free shipping': 799,
#  'new with tags': 1381,
#  'any questions please': 170,
#  'questions please ask': 1717,
#  'complete': 509,
#  'bottoms': 318,
#  'skirt': 1935,
#  'matching': 1247,
#  'suit': 2047,
#  'size': 1914,
#  'small': 1945,
#  'but': 385,
#  'straps': 2033,
#  'slightly': 1940,
#  'to': 2180,
#  'fit': 733,
#  'xs': 2456,
#  'that': 2108,
#  'perfect': 1590,
#  'size small': 1925,
#  'to fit': 2189,
#  'perfect condition': 1591,
#  'you': 2465,
#  'get': 834,
#  'three': 2171,
#  'pairs': 1565,
#  'shorts': 1888,
#  'medium': 1268,
#  'girls': 840,
#  'two': 2253,
#  'sports': 1996,
#  'bra': 333,
#  'boy': 331,
#  'spandex': 1992,
#  'sets': 1842,
#  'items': 1078,
#  'total': 2228,
#  'store': 2028,
#  'can': 409,
#  'take': 2076,
#  'today': 2209,
#  'less': 1142,
#  'than': 2100,
#  'price': 1669,
#  'one': 1489,
#  'item': 1075,
#  'at': 216,
#  'you get': 2473,
#  'pairs of': 1566,
#  'shorts size': 1889,
#  'small and': 1946,
#  'sports bra': 1997,
#  'all items': 98,
#  'and you': 161,
#  'you can': 2468,
#  'less than': 1143,
#  'the price': 2137,
#  'at the': 219,
#  'plus': 1646,
#  'green': 874,
#  'pants': 1570,
#  'after': 87,
#  'picture': 1607,
#  'were': 2357,
#  'very': 2306,
#  'dirty': 608,
#  'so': 1965,
#  'hand': 884,
#  'washed': 2336,
#  'them': 2145,
#  'he': 919,
#  'has': 900,
#  'body': 305,
#  'head': 920,
#  'hands': 891,
#  'feet': 717,
#  'before': 267,
#  'too': 2215,
#  'tall': 2079,
#  'or': 1508,
#  'cracks': 550,
#  'minor': 1287,
#  'paint': 1562,
#  'loss': 1203,
#  'few': 718,
#  'doll': 623,
#  'the picture': 2135,
#  'they were': 2156,
#  '25': 27,
#  'oz': 1549,
#  'full': 817,
#  'sephora': 1838,
#  'full size': 818,
#  'size is': 1922,
#  'vs': 2324,
#  'fresh': 806,
#  'clean': 462,
#  'sun': 2049,
#  'cool': 534,
#  'bright': 352,
#  'sweet': 2067,
#  'vs pink': 2325,
#  'xl': 2455,
#  'authentic': 221,
#  'suede': 2045,
#  'boots': 311,
#  'if': 962,
#  'between': 279,
#  'sizes': 1930,
#  'love': 1210,
#  'wearing': 2349,
#  'thick': 2157,
#  'socks': 1974,
#  'during': 645,
#  'winter': 2390,
#  'be': 250,
#  'well': 2355,
#  'did': 603,
#  'last': 1125,
#  'condition size': 520,
#  'if you': 964,
#  'you are': 2466,
#  'perfect for': 1592,
#  'for you': 781,
#  'as well': 205,
#  'great condition size': 869,
#  'if you are': 965,
#  'brand': 338,
#  'deluxe': 588,
#  'travel': 2237,
#  'products': 1690,
#  'contains': 529,
#  '12': 9,
#  'blush': 303,
#  'lip': 1172,
#  'birthday': 286,
#  'brand new': 340,
#  'travel size': 2238,
#  'glitter': 845,
#  'and one': 144,
#  'color': 482,
#  'coral': 535,
#  'retails': 1758,
#  'baby': 227,
#  'tan': 2081,
#  'made': 1221,
#  'fabric': 694,
#  'away': 225,
#  'moisture': 1301,
#  'sweat': 2064,
#  'over': 1543,
#  '90': 61,
#  'provides': 1699,
#  'unique': 2261,
#  'control': 531,
#  'weight': 2353,
#  'across': 73,
#  'double': 629,
#  'design': 594,
#  'shirt': 1879,
#  'new in': 1363,
#  'in box': 976,
#  'size medium': 1924,
#  'retails for': 1759,
#  'for the': 779,
#  'is made': 1047,
#  'made of': 1224,
#  'back and': 229,
#  'brand new in': 342,
#  'new in box': 1364,
#  'by': 404,
#  'faced': 696,
#  'mint': 1288,
#  'still': 2018,
#  'original': 1519,
#  'part': 1573,
#  'christmas': 458,
#  '2016': 20,
#  'collection': 481,
#  'pretty': 1668,
#  'eye': 688,
#  'shadow': 1848,
#  'colors': 488,
#  'sized': 1929,
#  'better': 278,
#  'mascara': 1244,
#  'never': 1347,
#  'even': 671,
#  'swatched': 2063,
#  'shape': 1850,
#  'includes': 1009,
#  'day': 573,
#  'priority': 1686,
#  'too faced': 2218,
#  'is brand': 1036,
#  'mint condition': 1289,
#  'still in': 2021,
#  'in original': 989,
#  'original box': 1520,
#  'part of': 1574,
#  'it has': 1065,
#  'eye shadow': 689,
#  'price includes': 1672,
#  'shipping with': 1876,
#  'is brand new': 1037,
#  'casual': 433,
#  'dress': 632,
#  'up': 2267,
#  'down': 630,
#  '100': 2,
#  'polyester': 1658,
#  'once': 1484,
#  'purchased': 1703,
#  'from': 810,
#  'people': 1588,
#  'dry': 639,
#  '100 polyester': 7,
#  'purchased from': 1704,
#  'free people': 795,
#  'worn': 2435,
#  'excellent': 678,
#  'worn once': 2442,
#  'excellent condition': 679,
#  'nwt': 1439,
#  'victoria': 2315,
#  'secret': 1824,
#  'ultimate': 2256,
#  'sport': 1995,
#  'support': 2057,
#  'victoria secret': 2316,
#  'reasonable': 1738,
#  'offers': 1458,
#  'lowest': 1214,
#  'll': 1189,
#  'phone': 1601,
#  'was': 2334,
#  'opened': 1507,
#  'under': 2258,
#  'mobile': 1299,
#  'now': 1435,
#  'been': 263,
#  'buttons': 399,
#  'used': 2280,
#  'check': 447,
#  'my': 1318,
#  'sorry': 1988,
#  'charger': 440,
#  'included': 1007,
#  'reasonable offers': 1739,
#  'like new': 1160,
#  'new still': 1376,
#  'it in': 1066,
#  'in perfect': 992,
#  'used condition': 2284,
#  'check my': 448,
#  'only': 1498,
#  'new never': 1367,
#  'never used': 1352,
#  'colors are': 489,
#  'brand new never': 343,
#  'new never used': 1370,
#  'listings': 1185,
#  'shop': 1884,
#  'ship': 1858,
#  'following': 754,
#  'days': 576,
#  'purchase': 1702,
#  'forever': 783,
#  '21': 22,
#  'brandy': 349,
#  'melville': 1269,
#  'baseball': 243,
#  'tee': 2093,
#  'never worn': 1354,
#  'my listings': 1323,
#  'the following': 2123,
#  'but it': 389,
#  'forever 21': 784,
#  'brandy melville': 350,
#  'lot': 1205,
#  'life': 1149,
#  'but they': 395,
#  'still have': 2020,
#  'lot of': 1206,
#  'of life': 1444,
#  'iphone': 1024,
#  '6s': 57,
#  'iphone plus': 1029,
#  'plus 6s': 1647,
#  '6s plus': 58,
#  'time': 2176,
#  'one time': 1495,
#  'beautiful': 259,
#  'ties': 2174,
#  'cream': 551,
#  'liner': 1168,
#  'bottom': 316,
#  'stretch': 2034,
#  'hollister': 948,
#  'jeans': 1089,
#  'see': 1826,
#  'tag': 2072,
#  'near': 1337,
#  'belt': 276,
#  'favorite': 710,
#  'please see': 1645,
#  'waterproof': 2339,
#  '17': 15,
#  'other': 1525,
#  'see my': 1827,
#  'my other': 1324,
#  'logo': 1191,
#  'band': 237,
#  'push': 1710,
#  'push up': 1711,
#  'unused': 2266,
#  'beauty': 260,
#  'mist': 1295,
#  'new unused': 1378,
#  'big': 280,
#  'dog': 622,
#  'retro': 1760,
#  'cute': 565,
#  'us': 2275,
#  'absolutely': 69,
#  'soft': 1975,
#  'genuine': 833,
#  'real': 1735,
#  'fur': 823,
#  'gorgeous': 863,
#  'long': 1192,
#  'candy': 418,
#  'panty': 1571,
#  'girl': 839,
#  'who': 2370,
#  'everything': 675,
#  'gift': 836,
#  'unicorn': 2260,
#  'princess': 1683,
#  'kitty': 1106,
#  'jewelry': 1092,
#  'wild': 2374,
#  'wedding': 2351,
#  'party': 1576,
#  'gift for': 837,
#  'fits': 735,
#  'super': 2051,
#  'leggings': 1136,
#  'waist': 2326,
#  'elastic': 661,
#  'one size': 1493,
#  'size fits': 1920,
#  'super soft': 2055,
#  'one size fits': 1494,
#  'pre': 1665,
#  'owned': 1548,
#  'some': 1982,
#  'light': 1151,
#  'scratches': 1812,
#  'hardware': 899,
#  'use': 2278,
#  'comes': 496,
#  'pre owned': 1666,
#  'scratches on': 1813,
#  'comes with': 500,
#  'wear': 2345,
#  'spots': 1999,
#  'which': 2364,
#  'believe': 273,
#  'has some': 906,
#  'some wear': 1983,
#  'to the': 2205,
#  'can be': 411,
#  'power': 1664,
#  'cord': 536,
#  'controller': 532,
#  'pack': 1550,
#  'games': 826,
#  'doesn': 621,
#  'the top': 2143,
#  'top is': 2223,
#  '34': 40,
#  'will': 2375,
#  'bundle': 365,
#  'save': 1802,
#  'feel': 713,
#  'will bundle': 2379,
#  'bundle to': 372,
#  'to save': 2197,
#  'save on': 1803,
#  'on shipping': 1475,
#  'you have': 2474,
#  'have any': 910,
#  'please feel': 1638,
#  'feel free': 714,
#  'free to': 804,
#  'to ask': 2183,
#  'bundle to save': 373,
#  'to save on': 2198,
#  'save on shipping': 1804,
#  'if you have': 966,
#  'you have any': 2475,
#  'have any questions': 911,
#  'please feel free': 1639,
#  'feel free to': 715,
#  'free to ask': 805,
#  'kylie': 1113,
#  'happy': 892,
#  'matte': 1249,
#  'mini': 1285,
#  'lipstick': 1175,
#  'kit': 1105,
#  'pcs': 1581,
#  'firm': 725,
#  'not': 1421,
#  'takes': 2078,
#  'usps': 2296,
#  'within': 2415,
#  '24': 25,
#  'hours': 955,
#  '48': 50,
#  'week': 2352,
#  'never opened': 1351,
#  'price is': 1673,
#  'is firm': 1038,
#  'will not': 2383,
#  'not be': 1422,
#  'ship within': 1861,
#  'within 24': 2416,
#  '24 hours': 26,
#  'new never opened': 1369,
#  'price is firm': 1674,
#  'within 24 hours': 2417,
#  'looks': 1200,
#  'ready': 1733,
#  'shipped': 1863,
#  'print': 1684,
#  'comfy': 504,
#  'quality': 1713,
#  'where': 2363,
#  'every': 673,
#  'lightly': 1156,
#  'lined': 1167,
#  'ships': 1877,
#  'same': 1792,
#  'seller': 1832,
#  'fee': 712,
#  'new and': 1357,
#  'and is': 139,
#  'ready to': 1734,
#  'to be': 2184,
#  'be shipped': 252,
#  'made by': 1222,
#  'secret pink': 1825,
#  '100 authentic': 3,
#  'free ship': 798,
#  'same day': 1793,
#  'shipping and': 1865,
#  'brand new and': 341,
#  'victoria secret pink': 2317,
#  '36': 42,
#  'will be': 2376,
#  'fast': 704,
#  'find': 722,
#  'more': 1306,
#  'sell': 1831,
#  'make': 1230,
#  'bundles': 377,
#  'fast free': 706,
#  'in my': 986,
#  'listings for': 1186,
#  'everything is': 676,
#  'is new': 1049,
#  'for free': 767,
#  'fast free shipping': 707,
#  'for free shipping': 768,
#  'smoking': 1960,
#  'bought': 319,
#  'ago': 91,
#  'return': 1761,
#  'these': 2150,
#  'things': 2160,
#  'buy': 400,
#  'piece': 1611,
#  'after you': 88,
#  'you buy': 2467,
#  'too big': 2216,
#  'big for': 281,
#  'for my': 774,
#  'too big for': 2217,
#  'black': 288,
#  'outside': 1542,
#  'gray': 865,
#  'inside': 1016,
#  'warm': 2333,
#  'runs': 1784,
#  'true': 2243,
#  'and in': 138,
#  'in like': 985,
#  'new condition': 1360,
#  'true to': 2244,
#  'to size': 2203,
#  'like new condition': 1161,
#  'true to size': 2245,
#  'slime': 1942,
#  'approximately': 180,
#  'kind': 1104,
#  'an': 119,
#  'air': 92,
#  'tight': 2175,
#  'container': 528,
#  'easy': 655,
#  'bath': 245,
#  'very soft': 2312,
#  'it is': 1067,
#  'this item': 2165,
#  'comes in': 499,
#  'bath and': 246,
#  'and body': 128,
#  'body works': 306,
#  'bath and body': 247,
#  'off': 1455,
#  'shoulder': 1891,
#  'crop': 554,
#  'euc': 670,
#  'sleeves': 1938,
#  'actual': 75,
#  'navy': 1335,
#  'blue': 300,
#  'stripes': 2039,
#  'crop top': 555,
#  'navy blue': 1336,
#  'blue and': 301,
#  'let': 1144,
#  'me': 1257,
#  'know': 1109,
#  'want': 2331,
#  'pictures': 1610,
#  'sure': 2059,
#  'discount': 610,
#  'usually': 2297,
#  'monday': 1302,
#  'post': 1661,
#  'office': 1459,
#  'issues': 1057,
#  'contact': 526,
#  'soon': 1987,
#  'super comfy': 2052,
#  'let me': 1145,
#  'me know': 1261,
#  'know if': 1110,
#  'you want': 2483,
#  'ask for': 212,
#  'are not': 188,
#  'not sure': 1429,
#  'the same': 2139,
#  'please contact': 1632,
#  'contact me': 527,
#  'as you': 207,
#  'let me know': 1146,
#  'me know if': 1262,
#  'know if you': 1111,
#  'if you want': 969,
#  'please contact me': 1633,
#  '3d': 45,
#  'lash': 1123,
#  'lashes': 1124,
#  'package': 1551,
#  'it will': 1073,
#  'in package': 990,
#  'never been': 1348,
#  'been opened': 264,
#  'ships within': 1878,
#  'new in package': 1365,
#  'sz': 2071,
#  'large': 1121,
#  'color black': 484,
#  'led': 1133,
#  'shoes': 1883,
#  'kids': 1103,
#  'red': 1742,
#  'purple': 1708,
#  'yellow': 2460,
#  'different': 605,
#  'unisex': 2262,
#  'boys': 332,
#  '10': 1,
#  'in one': 988,
#  'white and': 2368,
#  'year': 2458,
#  'vintage': 2320,
#  'hot': 953,
#  'bundle for': 368,
#  'colored': 486,
#  'strapless': 2032,
#  'cup': 560,
#  'message': 1274,
#  'message me': 1275,
#  'me with': 1264,
#  '2017': 21,
#  'rae': 1719,
#  'dunn': 643,
#  'holiday': 946,
#  'mug': 1313,
#  'another': 165,
#  'keep': 1099,
#  'give': 841,
#  'someone': 1984,
#  'special': 1993,
#  'we': 2343,
#  'care': 426,
#  'order': 1516,
#  'when': 2361,
#  'help': 929,
#  'rating': 1727,
#  'rae dunn': 1720,
#  'with care': 2398,
#  'your order': 2492,
#  'wood': 2426,
#  'necklace': 1339,
#  'earrings': 653,
#  'together': 2212,
#  'all are': 94,
#  'pure': 1707,
#  'honey': 950,
#  'stains': 2005,
#  'tears': 2091,
#  'target': 2084,
#  'condition no': 515,
#  'no stains': 1410,
#  'stains or': 2006,
#  'or tears': 1513,
#  'easy to': 656,
#  'to use': 2206,
#  'great condition no': 868,
#  'condition no stains': 517,
#  'no stains or': 1411,
#  'wireless': 2391,
#  'bluetooth': 302,
#  'diamond': 602,
#  'ring': 1767,
#  'most': 1310,
#  'this is': 2163,
#  'is very': 1056,
#  'bag': 234,
#  'hard': 895,
#  'background': 231,
#  'always': 112,
#  'bundling': 378,
#  'with tag': 2407,
#  'hard to': 896,
#  'to find': 2188,
#  'made in': 1223,
#  'check out': 449,
#  'out my': 1535,
#  'other listings': 1527,
#  'brand new with': 346,
#  'new with tag': 1380,
#  'hard to find': 897,
#  'check out my': 450,
#  'out my other': 1537,
#  'my other listings': 1326,
#  'other listings for': 1528,
#  'distressed': 614,
#  'slim': 1941,
#  'jeans size': 1090,
#  'size xs': 1928,
#  'denim': 589,
#  'of my': 1446,
#  'men': 1270,
#  'xxl': 2457,
#  'good': 855,
#  'mark': 1241,
#  'sleeve': 1937,
#  'in good': 980,
#  'good condition': 856,
#  'in good condition': 981,
#  '925': 62,
#  'closure': 470,
#  '16': 14,
#  'inches': 1005,
#  'length': 1138,
#  'flaws': 746,
#  'selling': 1833,
#  'don': 624,
#  '35': 41,
#  'cotton': 542,
#  '18': 16,
#  'no flaws': 1396,
#  'just don': 1096,
#  'wear it': 2347,
#  'condition no flaws': 516,
#  'armour': 193,
#  'half': 881,
#  'zip': 2497,
#  'jacket': 1087,
#  'awesome': 226,
#  'med': 1267,
#  'under armour': 2259,
#  'ratings': 1728,
#  'protection': 1695,
#  'extremely': 687,
#  'ignored': 971,
#  'factory': 698,
#  'sealed': 1820,
#  'packaging': 1553,
#  'asap': 208,
#  'page': 1559,
#  'cases': 432,
#  'allow': 106,
#  'tracking': 2233,
#  'please check': 1630,
#  'have no': 914,
#  'you purchase': 2479,
#  'be ignored': 251,
#  'my page': 1327,
#  'page for': 1560,
#  'will be ignored': 2377,
#  'will be shipped': 2378,
#  'my page for': 1328,
#  'overall': 1545,
#  'signs': 1902,
#  'signs of': 1903,
#  'of wear': 1453,
#  'signs of wear': 1904,
#  'fine': 723,
#  'fashion': 703,
#  'type': 2254,
#  'chain': 436,
#  '60': 56,
#  'cm': 474,
#  '15': 13,
#  'pictured': 1609,
#  'sample': 1797,
#  'highly': 939,
#  'scented': 1808,
#  'wax': 2340,
#  'essential': 668,
#  'oil': 1460,
#  'candle': 417,
#  'guaranteed': 877,
#  'safe': 1789,
#  'durable': 644,
#  'home': 949,
#  'fragrance': 789,
#  'amazing': 115,
#  'scent': 1807,
#  'night': 1389,
#  'room': 1775,
#  'business': 380,
#  'area': 191,
#  'house': 956,
#  'decor': 584,
#  'styles': 2042,
#  'compatible': 507,
#  'listed': 1180,
#  'profile': 1692,
#  'additional': 79,
#  'added': 78,
#  'per': 1589,
#  'regular': 1744,
#  'again': 89,
#  'our': 1533,
#  'in your': 1003,
#  'compatible with': 508,
#  'with any': 2395,
#  'high quality': 935,
#  'probably': 1688,
#  'best': 277,
#  'old': 1462,
#  'up to': 2269,
#  'extra': 686,
#  'responsible': 1753,
#  'new no': 1372,
#  'not responsible': 1427,
#  'responsible for': 1754,
#  'not responsible for': 1428,
#  'hold': 940,
#  'do': 615,
#  'these are': 2151,
#  'on hold': 1469,
#  'do not': 617,
#  'both': 312,
#  'come': 494,
#  'ones': 1496,
#  'then': 2146,
#  'burgundy': 379,
#  'separately': 1837,
#  'both are': 313,
#  'are brand': 182,
#  'not come': 1423,
#  'come with': 495,
#  'are brand new': 183,
#  'new never worn': 1371,
#  'not come with': 1424,
#  'stone': 2025,
#  'look': 1196,
#  'details': 598,
#  'crystal': 559,
#  'with the': 2410,
#  'brown': 357,
#  'sheer': 1852,
#  'flower': 750,
#  'front': 815,
#  'without': 2419,
#  'shade': 1846,
#  'cosmetics': 538,
#  'ml': 1298,
#  'coverage': 549,
#  'looking': 1198,
#  'brands': 348,
#  'through': 2172,
#  'search': 1821,
#  'using': 2295,
#  'space': 1990,
#  'above': 68,
#  'new without': 1382,
#  'original packaging': 1521,
#  'looking for': 1199,
#  'don have': 626,
#  'all my': 100,
#  'so you': 1972,
#  'need': 1340,
#  'create': 552,
#  'follow': 753,
#  'natural': 1334,
#  'line': 1166,
#  'features': 711,
#  'powder': 1663,
#  'thin': 2158,
#  'brush': 358,
#  'apply': 178,
#  'effect': 659,
#  'you need': 2478,
#  'need to': 1341,
#  'you to': 2482,
#  'have the': 916,
#  'used to': 2294,
#  'sheet': 1853,
#  'set': 1840,
#  'fading': 700,
#  'fully': 819,
#  'flat': 742,
#  'pillow': 1615,
#  'fitted': 737,
#  'trim': 2242,
#  'hot pink': 954,
#  'light pink': 1153,
#  'dvd': 648,
#  'include': 1006,
#  'rise': 1771,
#  'disc': 609,
#  'workout': 2431,
#  'set of': 1841,
#  'and the': 155,
#  'play': 1624,
#  'used but': 2283,
#  'but still': 393,
#  'tops': 2227,
#  'season': 1822,
#  'anymore': 171,
#  'condition worn': 523,
#  'good used': 861,
#  'good used condition': 862,
#  'holes': 944,
#  'taken': 2077,
#  '11': 8,
#  'spring': 2001,
#  'summer': 2048,
#  'fall': 702,
#  'great shape': 873,
#  'size 11': 1916,
#  'show': 1892,
#  'wear and': 2346,
#  'toy': 2231,
#  'canvas': 420,
#  'gently': 830,
#  'loved': 1211,
#  'lots': 1208,
#  'left': 1134,
#  'wash': 2335,
#  'son': 1986,
#  'wore': 2427,
#  'lots of': 1209,
#  'life left': 1150,
#  'no holes': 1401,
#  'of life left': 1445,
#  'won': 2425,
#  'though': 2170,
#  'system': 2070,
#  'completely': 510,
#  'second': 1823,
#  'shows': 1897,
#  'cost': 539,
#  'how': 957,
#  'ordered': 1517,
#  'shades': 1847,
#  'match': 1246,
#  'face': 695,
#  'primer': 1682,
#  'their': 2144,
#  'website': 2350,
#  'and they': 156,
#  'me for': 1259,
#  'it was': 1072,
#  'it and': 1059,
#  ...}

# %%
# create a dictionary mapping the tokens to their tfidf values
tfidf = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))
tfidf_df = pd.DataFrame(columns=["description_text_tfidf"]).from_dict(dict(tfidf), orient='index')
tfidf_df.columns = ["description_text_tfidf"]

# %%
tfidf_df.shape
# Out:
# (2500, 1)

# %%
# features with highest tf-idf (in title)
top_n_tfidf = tfidf_df.sort_values(by=["description_text_tfidf"], ascending=False).head(100)
top_n_tfidf
# Out:
#             description_text_tfidf
# pipes                     9.532511
# note note                 8.140242
# teeth                     7.754545
# s6 edge                   7.723212
# generation                7.717619
# ...                            ...
# peel                      7.245109
# max                       7.245109
# your skin                 7.244066
# bra size                  7.243372
# legs                      7.241984
#
# [100 rows x 1 columns]

# %%
tfidf_df.to_dict()
# Out:
# {'description_text_tfidf': {'00': 6.609201908111572,
#   '10': 4.2809906005859375,
#   '100': 4.332520008087158,
#   '100 authentic': 5.300342082977295,
#   '100 brand': 6.821724891662598,
#   '100 brand new': 6.82628870010376,
#   '100 cotton': 6.781996250152588,
#   '100 polyester': 7.100942611694336,
#   '11': 5.499847412109375,
#   '12': 4.786893844604492,
#   '13': 5.896909236907959,
#   '14': 5.570263862609863,
#   '14k': 7.381226539611816,
#   '15': 5.58800745010376,
#   '16': 5.642789363861084,
#   '17': 6.400447368621826,
#   '18': 5.509363174438477,
#   '19': 6.9482550621032715,
#   '1x': 6.629848003387451,
#   '20': 5.517424583435059,
#   '2016': 6.845222473144531,
#   '2017': 6.940276622772217,
#   '21': 5.612709999084473,
#   '22': 6.4055399894714355,
#   '23': 7.027264595031738,
#   '24': 5.367812156677246,
#   '24 hours': 6.640998363494873,
#   '25': 5.740413665771484,
#   '26': 6.555619239807129,
#   '27': 6.744839668273926,
#   '28': 6.482945919036865,
#   '29': 6.924255847930908,
#   '2nd': 6.892719745635986,
#   '2t': 7.110621929168701,
#   '2x': 6.648054599761963,
#   '2xl': 7.205233097076416,
#   '30': 5.4947004318237305,
#   '31': 6.958122730255127,
#   '32': 6.306401252746582,
#   '33': 7.113056182861328,
#   '34': 6.598581314086914,
#   '35': 6.858362197875977,
#   '36': 6.72894287109375,
#   '360': 7.034843444824219,
#   '38': 7.025588035583496,
#   '3d': 7.304929733276367,
#   '3rd': 6.9047698974609375,
#   '3t': 7.026985168457031,
#   '3x': 7.075970649719238,
#   '40': 6.310489177703857,
#   '48': 7.226848125457764,
#   '4t': 7.252087593078613,
#   '4th': 7.002681255340576,
#   '50': 6.017088413238525,
#   '5c': 6.692671775817871,
#   '5s': 6.388269901275635,
#   '60': 6.579993724822998,
#   '6s': 5.797208786010742,
#   '6s plus': 6.487499237060547,
#   '75': 6.722530841827393,
#   '80': 7.1656012535095215,
#   '90': 6.848959445953369,
#   '925': 6.838948726654053,
#   '95': 7.201231956481934,
#   'abercrombie': 7.064875602722168,
#   'able': 6.883716583251953,
#   'able to': 7.015035152435303,
#   'about': 4.981305122375488,
#   'above': 6.45415735244751,
#   'absolutely': 6.670701503753662,
#   'accents': 7.1458868980407715,
#   'accessories': 6.355170726776123,
#   'acne': 7.570584774017334,
#   'across': 6.777193546295166,
#   'acrylic': 7.310482501983643,
#   'actual': 6.897620677947998,
#   'adapter': 7.319430828094482,
#   'add': 5.667679786682129,
#   'added': 6.865948677062988,
#   'additional': 6.133255958557129,
#   'adhesive': 7.03851318359375,
#   'adidas': 6.115570545196533,
#   'adjust': 7.1857123374938965,
#   'adjustable': 5.444464683532715,
#   'adjustable straps': 7.124393939971924,
#   'adorable': 6.011401653289795,
#   'adult': 6.921988010406494,
#   'after': 5.269927501678467,
#   'after you': 7.101243495941162,
#   'again': 6.964667797088623,
#   'age': 7.236109256744385,
#   'ago': 7.031187057495117,
#   'air': 6.0582499504089355,
#   'all': 3.4110400676727295,
#   'all are': 6.790566921234131,
#   'all brand': 7.0032267570495605,
#   'all brand new': 7.016140937805176,
#   'all in': 6.555444717407227,
#   'all items': 6.1077351570129395,
#   'all items are': 6.918219566345215,
#   'all my': 6.509416580200195,
#   'all new': 6.823775768280029,
#   'all of': 6.287139892578125,
#   'all orders': 7.305299282073975,
#   'all sales': 6.848257541656494,
#   'all the': 6.274282455444336,
#   'allow': 6.9343976974487305,
#   'almost': 6.296252727508545,
#   'along': 7.00705623626709,
#   'already': 6.421891689300537,
#   'also': 4.5972490310668945,
#   'also have': 6.780465602874756,
#   'always': 5.7314958572387695,
#   'am': 5.447110176086426,
#   'am not': 7.201897621154785,
#   'amazing': 5.921778202056885,
#   'american': 5.631784439086914,
#   'american eagle': 6.20631742477417,
#   'amount': 6.878883361816406,
#   'an': 4.4865922927856445,
#   'an offer': 6.491418838500977,
#   'anastasia': 6.982423782348633,
#   'and': 2.090604066848755,
#   'and all': 7.21193790435791,
#   'and are': 6.818542003631592,
#   'and back': 7.060819149017334,
#   'and black': 6.029486656188965,
#   'and blue': 6.984565258026123,
#   'and body': 6.858834743499756,
#   'and can': 6.777193546295166,
#   'and comfortable': 6.895657539367676,
#   'and comfy': 7.118862628936768,
#   'and free': 6.721294403076172,
#   'and free shipping': 7.097336769104004,
#   'and gold': 7.186367988586426,
#   'and has': 6.42341947555542,
#   'and have': 6.635502338409424,
#   'and high': 7.154424667358398,
#   'and in': 6.266803741455078,
#   'and is': 6.176855564117432,
#   'and it': 5.891775608062744,
#   'and more': 6.619007110595703,
#   'and never': 6.280094146728516,
#   'and no': 6.81491756439209,
#   'and one': 6.573400020599365,
#   'and other': 7.1094069480896,
#   'and pet': 6.0877556800842285,
#   'and pet free': 6.110302925109863,
#   'and pink': 6.809279918670654,
#   'and save': 5.4560770988464355,
#   'and save on': 7.064295291900635,
#   'and sealed': 7.005960464477539,
#   'and shipping': 7.105467796325684,
#   'and smoke': 6.785503387451172,
#   'and smoke free': 6.800548076629639,
#   'and the': 5.413084030151367,
#   'and they': 6.5924072265625,
#   'and very': 7.144942760467529,
#   'and washed': 6.757997512817383,
#   'and white': 5.539981842041016,
#   'and will': 6.075589179992676,
#   'and you': 6.891010284423828,
#   'android': 7.268681049346924,
#   'animal': 7.163997173309326,
#   'ankle': 6.882989883422852,
#   'another': 6.3132243156433105,
#   'anti': 6.648054599761963,
#   'any': 4.078361511230469,
#   'any other': 7.029784679412842,
#   'any questions': 5.013592720031738,
#   'any questions please': 6.554573059082031,
#   'anymore': 6.347347736358643,
#   'anything': 6.265627861022949,
#   'app': 7.168173789978027,
#   'apparel': 6.995882987976074,
#   'apple': 5.988479137420654,
#   'apple iphone': 7.427708625793457,
#   'application': 7.217334270477295,
#   'apply': 6.709421157836914,
#   'approx': 6.3982086181640625,
#   'approximately': 6.7726311683654785,
#   'are': 3.2999351024627686,
#   'are brand': 6.504264831542969,
#   'are brand new': 6.512253284454346,
#   'are final': 7.17657995223999,
#   'are firm': 6.493220806121826,
#   'are in': 5.756213665008545,
#   'are new': 6.577493667602539,
#   'are not': 6.429861068725586,
#   'are size': 6.628721237182617,
#   'are the': 6.8278913497924805,
#   'area': 6.617706298828125,
#   'arm': 7.292457103729248,
#   'armour': 6.699700355529785,
#   'around': 5.370742321014404,
#   'around the': 6.685492992401123,
#   'arrive': 6.771764278411865,
#   'art': 7.17657995223999,
#   'as': 3.806835174560547,
#   'as gift': 6.950324058532715,
#   'as is': 6.876234531402588,
#   'as pictured': 6.822408199310303,
#   'as seen': 6.922491550445557,
#   'as shown': 6.061757564544678,
#   'as shown in': 6.5983991622924805,
#   'as well': 5.819272994995117,
#   'as well as': 7.181461811065674,
#   'as you': 6.74105167388916,
#   'asap': 6.992095947265625,
#   'ask': 4.486636161804199,
#   'ask any': 6.518622398376465,
#   'ask any questions': 6.674821376800537,
#   'ask for': 6.477928161621094,
#   'ask me': 6.56367826461792,
#   'ask questions': 6.814465045928955,
#   'asking': 6.566673278808594,
#   'at': 4.220993518829346,
#   'at all': 6.522328853607178,
#   'at my': 7.121931552886963,
#   'at the': 5.714723110198975,
#   'attached': 6.144065856933594,
#   'authentic': 4.185387134552002,
#   'available': 4.803820610046387,
#   'available for': 6.88178014755249,
#   'available in': 6.470689296722412,
#   'away': 6.491091728210449,
#   'awesome': 6.275205135345459,
#   'baby': 5.351036071777344,
#   'back': 4.270566463470459,
#   'back and': 7.11580228805542,
#   'back of': 6.780247211456299,
#   'background': 6.253687381744385,
#   'backpack': 6.833865642547607,
#   'bad': 6.817861557006836,
#   'bag': 4.632603168487549,
#   'bags': 6.446305751800537,
#   'ball': 6.703941822052002,
#   'band': 5.868861198425293,
#   'bar': 7.059662818908691,
#   'barely': 5.882297515869141,
#   'barely used': 6.965193271636963,
#   'barely worn': 6.944643974304199,
#   'base': 6.742733478546143,
#   'baseball': 7.258762359619141,
#   'based': 7.14683198928833,
#   'bath': 6.194574356079102,
#   'bath and': 7.156331539154053,
#   'bath and body': 7.229925632476807,
#   'batteries': 6.889547348022461,
#   'battery': 6.2316131591796875,
#   'be': 3.7417445182800293,
#   'be ignored': 6.972050189971924,
#   'be shipped': 6.484569549560547,
#   'be sure': 7.10849666595459,
#   'be used': 6.195669174194336,
#   'be worn': 6.571093559265137,
#   'beach': 6.543651580810547,
#   'beads': 7.078028202056885,
#   'bear': 7.379634380340576,
#   'beautiful': 4.7130303382873535,
#   'beauty': 5.865617752075195,
#   'because': 5.325826644897461,
#   'because it': 7.0721611976623535,
#   'been': 4.308164596557617,
#   'been opened': 7.138983726501465,
#   'been used': 5.670124530792236,
#   'been worn': 5.608776092529297,
#   'before': 4.685523509979248,
#   'before buying': 7.073331832885742,
#   'before purchasing': 6.466211795806885,
#   'before you': 7.134926795959473,
#   'beige': 6.36781644821167,
#   'being': 6.311855792999268,
#   'believe': 7.150937557220459,
#   'belly': 7.370527267456055,
#   'below': 6.269028663635254,
#   'belt': 6.449282169342041,
#   'best': 5.462723255157471,
#   'better': 6.124714374542236,
#   'between': 7.0216875076293945,
#   'big': 5.382388114929199,
#   'big for': 6.93414306640625,
#   'big for me': 7.114581108093262,
#   'bigger': 6.928047180175781,
#   'bikini': 6.5871710777282715,
#   'bio': 6.728735446929932,
#   'birthday': 6.732060432434082,
#   'bit': 6.021374225616455,
#   'black': 3.3930766582489014,
#   'black and': 5.523000717163086,
#   'black and white': 6.318854331970215,
#   'black background': 7.197909355163574,
#   'black size': 7.040778160095215,
#   'black white': 6.730604648590088,
#   'black with': 6.461753845214844,
#   'blanket': 7.378044605255127,
#   'blend': 6.629096508026123,
#   'bling': 6.909978866577148,
#   'blocked': 6.895902633666992,
#   'blouse': 6.900572776794434,
#   'blue': 4.139210224151611,
#   'blue and': 6.4112629890441895,
#   'bluetooth': 6.938739776611328,
#   'blush': 6.428630828857422,
#   'bnwt': 6.172206878662109,
#   'body': 5.052298545837402,
#   'body works': 6.72542142868042,
#   'boho': 7.0153117179870605,
#   'book': 6.444430351257324,
#   'books': 7.123162269592285,
#   'boot': 6.650353908538818,
#   'boots': 5.6974873542785645,
#   'both': 4.856518268585205,
#   'both are': 7.013655185699463,
#   'bottle': 5.891865253448486,
#   'bottles': 6.789022922515869,
#   'bottom': 5.085638046264648,
#   'bottom of': 6.880330562591553,
#   'bottoms': 6.2455925941467285,
#   'bought': 4.83868408203125,
#   'bought for': 7.091057777404785,
#   'bought from': 6.903286457061768,
#   'bought it': 6.90254545211792,
#   'bought this': 7.122854232788086,
#   'boutique': 6.875033378601074,
#   'bow': 6.724801540374756,
#   'box': 3.789430856704712,
#   'box and': 6.640428066253662,
#   'box is': 7.08570671081543,
#   'box never': 7.02894401550293,
#   'boxes': 6.6634840965271,
#   'boy': 6.615480899810791,
#   'boys': 6.082088470458984,
#   'bra': 5.385578155517578,
#   'bra size': 7.243371963500977,
#   'bracelet': 6.115907669067383,
#   'bracelets': 7.390432357788086,
#   'bralette': 6.9570794105529785,
#   'brand': 2.743384838104248,
#   'brand is': 7.051607608795166,
#   'brand new': 2.8609375953674316,
#   'brand new and': 5.915778636932373,
#   'brand new in': 5.313758850097656,
#   'brand new never': 4.825637340545654,
#   'brand new sealed': 6.636258602142334,
#   'brand new size': 7.045039176940918,
#   'brand new with': 4.965312957763672,
#   'brand new without': 6.832943916320801,
#   'brands': 6.544168949127197,
#   'brandy': 6.3586039543151855,
#   'brandy melville': 6.457632064819336,
#   'bras': 6.81718111038208,
#   'bright': 6.32520866394043,
#   'broken': 7.061397552490234,
#   'bronze': 7.26370906829834,
#   'bronzer': 7.220382213592529,
#   'brow': 7.27510929107666,
#   'brown': 5.22581148147583,
#   'brush': 5.768924236297607,
#   'brushes': 6.817634582519531,
#   'bubble': 6.267065048217773,
#   'bubble wrap': 7.076851844787598,
#   'buckle': 6.820132255554199,
#   'built': 6.621240139007568,
#   'built in': 6.751821517944336,
#   'bundle': 3.5742809772491455,
#   'bundle and': 5.5667524337768555,
#   'bundle and save': 5.730731010437012,
#   'bundle for': 6.129261016845703,
#   'bundle items': 6.99914026260376,
#   'bundle of': 6.762494087219238,
#   'bundle save': 7.06982421875,
#   'bundle to': 5.417435169219971,
#   'bundle to save': 5.489759922027588,
#   'bundle with': 6.134285926818848,
#   'bundle with other': 6.942586421966553,
#   'bundled': 6.455419540405273,
#   'bundles': 5.6217217445373535,
#   'bundling': 6.558940410614014,
#   'burgundy': 6.784186840057373,
#   'business': 5.50740385055542,
#   'business day': 6.430630683898926,
#   'business days': 6.252527236938477,
#   'business days to': 7.083042144775391,
#   'bust': 6.828578948974609,
#   'but': 3.3824048042297363,
#   'but can': 6.771547794342041,
#   'but fits': 6.6221723556518555,
#   'but in': 6.617520809173584,
#   'but it': 5.8047566413879395,
#   'but never': 6.652658462524414,
#   'but no': 6.787261486053467,
#   'but not': 6.498645305633545,
#   'but still': 6.111868858337402,
#   'but the': 6.736023426055908,
#   'but they': 6.598581314086914,
#   'but will': 7.0871901512146,
#   'butter': 7.122239112854004,
#   'button': 5.692911148071289,
#   'buttons': 6.436809539794922,
#   'buy': 5.051406383514404,
#   'buyer': 6.7067790031433105,
#   'buyers': 6.878401279449463,
#   'buying': 6.325069904327393,
#   'by': 4.330331325531006,
#   'by the': 6.948513507843018,
#   'cable': 6.220444202423096,
#   'came': 6.605893611907959,
#   'camera': 6.695276737213135,
#   'can': 3.7789385318756104,
#   'can also': 7.1439995765686035,
#   'can be': 5.0734758377075195,
#   'can be used': 6.527744293212891,
#   'can be worn': 6.8671393394470215,
#   'can bundle': 7.163355827331543,
#   'can fit': 6.648245811462402,
#   'can see': 6.676788806915283,
#   'candle': 7.177879333496094,
#   'candy': 6.6266584396362305,
#   'cannot': 7.033154487609863,
#   'canvas': 7.148408889770508,
#   'cap': 6.905017375946045,
#   'car': 6.464457988739014,
#   'card': 5.74335241317749,
#   'cardigan': 6.875753879547119,
#   'cards': 6.3490495681762695,
#   'care': 5.6118268966674805,
#   'carefully': 7.073624610900879,
#   'carly': 7.150304794311523,
#   'carry': 6.823547840118408,
#   'case': 4.691537857055664,
#   'case for': 6.808605194091797,
#   'cases': 6.410206317901611,
#   'casual': 7.013103485107422,
#   'cat': 6.687283039093018,
#   'cell': 7.307517051696777,
#   'chain': 6.189479827880859,
#   'change': 6.726456165313721,
#   'charcoal': 7.0051398277282715,
#   'charge': 6.799656867980957,
#   'charger': 5.634559154510498,
#   'charging': 6.635691165924072,
#   'charlotte': 6.98832368850708,
#   'charlotte russe': 7.061397552490234,
#   'charm': 6.586811065673828,
#   'charms': 7.40378999710083,
#   'cheap': 6.600221633911133,
#   'check': 4.402510643005371,
#   'check my': 6.326040267944336,
#   'check out': 4.731863975524902,
#   'check out my': 4.917966842651367,
#   'chest': 6.845688819885254,
#   'chic': 7.1857123374938965,
#   'children': 6.807033538818359,
#   'chocolate': 7.018078804016113,
#   'choice': 6.946447849273682,
#   'choker': 6.943357467651367,
#   'choose': 6.445211410522461,
#   'christmas': 5.798353672027588,
#   'clasp': 7.122854232788086,
#   'class': 6.437429428100586,
#   'classic': 6.041309833526611,
#   'clean': 5.271810531616211,
#   'cleaned': 6.5913214683532715,
#   'cleaning': 6.488151550292969,
#   'clear': 5.793863296508789,
#   'clip': 6.723768711090088,
#   'close': 6.794104099273682,
#   'closet': 5.502583026885986,
#   'closet for': 6.981622219085693,
#   'closure': 5.9201130867004395,
#   'cloth': 6.998596668243408,
#   'clothes': 6.504264831542969,
#   'clothing': 6.591864109039307,
#   'cm': 7.440731525421143,
#   'coach': 6.205333709716797,
#   'coat': 6.845222473144531,
#   'coconut': 7.075090408325195,
#   'coffee': 6.930074691772461,
#   'cold': 6.600404262542725,
#   'collar': 6.993987560272217,
#   'collection': 5.723340034484863,
#   'color': 3.641491174697876,
#   'color and': 6.806360721588135,
#   'color black': 6.283677577972412,
#   'color is': 6.014850616455078,
#   'colored': 6.166987895965576,
#   'colorful': 7.1636762619018555,
#   'colors': 4.771831035614014,
#   'colors are': 7.208580017089844,
#   'colors available': 7.0593743324279785,
#   'combine': 6.194087982177734,
#   'combine shipping': 6.947221755981445,
#   'combined': 7.192946910858154,
#   'come': 5.097909450531006,
#   'come with': 5.813939571380615,
#   'comes': 4.134720325469971,
#   'comes from': 6.120865821838379,
#   'comes from smoke': 6.4202141761779785,
#   'comes in': 6.49338436126709,
#   'comes with': 4.49571418762207,
#   'comes with box': 7.149040222167969,
#   'comfort': 6.738325119018555,
#   'comfortable': 5.318153381347656,
#   'comfy': 5.74141788482666,
#   'comment': 5.581003665924072,
#   'comments': 6.6992974281311035,
#   'compatible': 6.322026252746582,
#   'compatible with': 6.645951747894287,
#   'complete': 6.424489974975586,
#   'completely': 6.9749650955200195,
#   'concealer': 6.845222473144531,
#   'condition': 2.7976341247558594,
#   'condition and': 6.523510932922363,
#   'condition comes': 7.1458868980407715,
#   'condition no': 5.320992469787598,
#   'condition no flaws': 7.0128278732299805,
#   'condition no stains': 7.147778034210205,
#   'condition only': 6.41428804397583,
#   'condition only worn': 7.141801834106445,
#   'condition size': 5.820611000061035,
#   'condition the': 7.114886283874512,
#   'condition with': 6.70414400100708,
#   'condition worn': 6.688079357147217,
#   'conditioner': 7.3471527099609375,
#   'conditions': 6.92678165435791,
#   'contact': 5.8839898109436035,
#   'contact me': 6.330627918243408,
#   'container': 7.277620792388916,
#   'contains': 6.501781940460205,
#   'contour': 6.78462553024292,
#   'control': 6.4904375076293945,
#   'controller': 7.28013801574707,
#   'converse': 7.051321029663086,
#   'cool': 6.1951823234558105,
#   'coral': 6.667573928833008,
#   'cord': 6.597125053405762,
#   'cosmetic': 6.9880547523498535,
#   'cosmetics': 6.509416580200195,
#   'cost': 6.589695453643799,
#   'costs': 7.009251117706299,
#   'costume': 6.939764022827148,
#   'cotton': 5.334845542907715,
#   'could': 5.791016101837158,
#   'couple': 5.555970668792725,
#   'couple of': 6.485382556915283,
#   'couple of times': 6.840107440948486,
#   'couple times': 6.5493574142456055,
#   'cover': 5.758727073669434,
#   'coverage': 6.886141777038574,
#   'cracks': 7.122239112854004,
#   'cream': 5.485621929168701,
#   'create': 6.547451972961426,
#   'crew': 6.802779674530029,
#   'crop': 6.487662315368652,
#   'crop top': 7.013930797576904,
#   'cropped': 7.177554130554199,
#   'cross': 6.4403791427612305,
#   'crossbody': 6.977888584136963,
#   'crystal': 6.745683193206787,
#   'cup': 6.308170795440674,
#   'cups': 6.702930450439453,
#   'curvy': 6.983493804931641,
#   'custom': 6.292892932891846,
#   'cut': 5.7508931159973145,
#   'cute': 4.067547798156738,
#   'cute and': 6.202755451202393,
#   'daily': 6.609385967254639,
#   'damage': 6.1178202629089355,
#   'damaged': 7.047318935394287,
#   'dark': 5.166406631469727,
#   'date': 6.9047698974609375,
#   'daughter': 6.840571403503418,
#   'day': 4.4905009269714355,
#   'day or': 7.09344482421875,
#   'day shipping': 6.269421577453613,
#   'days': 5.1448493003845215,
#   'days to': 6.779592037200928,
#   'days to arrive': 7.168173789978027,
#   'de': 7.084817886352539,
#   'deal': 5.923724174499512,
#   'deals': 6.305177688598633,
#   'decal': 7.455641269683838,
#   'decay': 6.822863578796387,
#   'decor': 6.771114826202393,
#   'deep': 6.150794506072998,
#   'defects': 6.95473575592041,
#   'delivery': 6.931344509124756,
#   'deluxe': 7.191627502441406,
#   'denim': 6.407644748687744,
#   'depending': 6.835480213165283,
#   'depending on': 6.891742706298828,
#   'description': 3.782104015350342,
#   'description yet': 3.88703989982605,
#   'design': 5.259036540985107,
#   'designed': 6.617892265319824,
#   'designs': 6.986711025238037,
#   'detail': 6.260029315948486,
#   'details': 5.85214376449585,
#   'device': 7.235075950622559,
#   'devices': 7.428544044494629,
#   'diameter': 7.212947368621826,
#   'diamond': 6.674821376800537,
#   'did': 6.811531066894531,
#   'didn': 6.158975601196289,
#   'different': 5.5624775886535645,
#   'dimensions': 7.111534118652344,
#   'dirt': 7.032029628753662,
#   'dirty': 7.004046440124512,
#   'disc': 7.075677394866943,
#   'discount': 5.686013221740723,
#   'discounts': 6.1714935302734375,
#   'disney': 5.993041515350342,
#   'display': 6.814239025115967,
#   'distressed': 6.856945991516113,
#   'do': 4.597372055053711,
#   'do bundle': 7.190310001373291,
#   'do not': 5.287740707397461,
#   'does': 5.428679466247559,
#   'does have': 7.140861511230469,
#   'does not': 5.933604717254639,
#   'doesn': 5.941127300262451,
#   'dog': 6.351322650909424,
#   'doll': 6.747795581817627,
#   'don': 4.552805423736572,
#   'don ask': 6.505425930023193,
#   'don have': 6.808605194091797,
#   'dont': 6.853884696960449,
#   'dot': 7.0045928955078125,
#   'double': 6.155227184295654,
#   'down': 5.661880970001221,
#   'drawstring': 6.9544758796691895,
#   'dress': 4.766305923461914,
#   'dress size': 7.058219909667969,
#   'dress with': 7.089568614959717,
#   'dresses': 7.10698127746582,
#   'dri': 7.127171516418457,
#   'dri fit': 7.156968116760254,
#   'drop': 6.442091464996338,
#   'dry': 5.750424861907959,
#   'dual': 7.207240104675293,
#   'due': 6.002129554748535,
#   'due to': 6.022909641265869,
#   'dunn': 6.233002662658691,
#   'durable': 6.398805141448975,
#   'during': 6.7883620262146,
#   'dust': 6.23756217956543,
#   'dust bag': 6.70535945892334,
#   'dvd': 6.946963787078857,
#   'dye': 7.268324851989746,
#   'each': 4.748908042907715,
#   'eagle': 6.174468994140625,
#   'ear': 7.209921836853027,
#   'earrings': 6.207056045532227,
#   'easily': 6.4058403968811035,
#   'easy': 5.4772772789001465,
#   'easy to': 6.186580181121826,
#   'edge': 6.843359470367432,
#   'edition': 5.732491493225098,
#   'effect': 7.197909355163574,
#   'either': 7.065747261047363,
#   'elastic': 6.25588321685791,
#   'else': 6.8081560134887695,
#   'embroidered': 7.250338077545166,
#   'end': 6.705967426300049,
#   'enjoy': 6.804568767547607,
#   'enough': 6.826746463775635,
#   'envelope': 7.192286968231201,
#   'essential': 7.016971111297607,
#   'etc': 5.920760154724121,
#   'euc': 5.946521759033203,
#   'even': 5.772266864776611,
#   'ever': 6.479220867156982,
#   'every': 6.008469581604004,
#   'everyday': 7.085114002227783,
#   'everything': 5.4975433349609375,
#   'everything is': 7.150304794311523,
#   'exact': 6.8728742599487305,
#   'excellent': 4.46248722076416,
#   'excellent condition': 4.755029201507568,
#   'excellent condition no': 7.110925674438477,
#   'excellent used': 6.842196941375732,
#   'excellent used condition': 6.863334655761719,
#   'except': 6.4582648277282715,
#   'exclusive': 6.546932697296143,
#   'express': 6.95395565032959,
#   'extra': 5.463893890380859,
#   'extremely': 6.853649616241455,
#   'eye': 5.8083038330078125,
#   'eye shadow': 7.288818359375,
#   'eyeliner': 6.981889247894287,
#   'eyes': 6.6615424156188965,
#   'eyeshadow': 6.161561012268066,
#   'eyeshadow palette': 7.285192489624023,
#   'fabric': 5.76345682144165,
#   'face': 5.604250431060791,
#   'faced': 6.8301849365234375,
#   'facial': 7.366593360900879,
#   'factory': 6.704346656799316,
#   'faded': 6.934652805328369,
#   'fading': 6.6652350425720215,
#   'fair': 6.556142807006836,
#   'fall': 6.065598487854004,
#   'fashion': 6.120527267456055,
#   'fast': 5.0459160804748535,
#   'fast and': 7.105467796325684,
#   'fast free': 6.721706390380859,
#   'fast free shipping': 6.797431945800781,
#   'fast shipping': 6.060799598693848,
#   'faux': 6.363919258117676,
#   'favorite': 6.50609016418457,
#   'features': 5.694680213928223,
#   'fee': 6.795877456665039,
#   'feel': 5.0913920402526855,
#   'feel free': 5.419730186462402,
#   'feel free to': 5.426025867462158,
#   'fees': 6.856238842010498,
#   'feet': 6.789243221282959,
#   'few': 4.758002758026123,
#   'few times': 5.340575695037842,
#   'figure': 6.98832368850708,
#   'final': 6.292624473571777,
#   'find': 5.4940361976623535,
#   'fine': 6.215713024139404,
#   'finish': 6.316103935241699,
#   'firm': 3.825218677520752,
#   'firm no': 6.150561332702637,
#   'firm no free': 6.723562240600586,
#   'firm please': 7.066038131713867,
#   'firm price': 6.423113822937012,
#   'firm unless': 6.915464878082275,
#   'first': 5.434918403625488,
#   'first class': 6.650545597076416,
#   'fit': 4.228967666625977,
#   'fit me': 6.692271709442139,
#   'fits': 4.612130165100098,
#   'fits like': 6.498480319976807,
#   'fitted': 6.738534450531006,
#   'fix': 7.224461078643799,
#   'fl': 6.0138349533081055,
#   'fl oz': 6.051060199737549,
#   'flash': 7.1336822509765625,
#   'flat': 6.246744632720947,
#   'flattering': 7.039361953735352,
#   'flaw': 6.615110397338867,
#   'flawless': 7.119168758392334,
#   'flaws': 4.891055107116699,
#   'fleece': 6.552831649780273,
#   'flexible': 7.224461078643799,
#   'floral': 5.772585868835449,
#   'flower': 6.721088409423828,
#   'flowers': 6.920730113983154,
#   'foam': 7.291728496551514,
#   'follow': 6.412169456481934,
#   'following': 6.65362024307251,
#   'foot': 7.31718635559082,
#   'for': 2.4286398887634277,
#   'for all': 5.964232921600342,
#   'for an': 7.153472423553467,
#   'for any': 6.248668670654297,
#   'for both': 6.924760341644287,
#   'for bundle': 7.013379096984863,
#   'for discount': 7.172691345214844,
#   'for each': 7.063714981079102,
#   'for fall': 7.06255578994751,
#   'for for': 6.6936726570129395,
#   'for for for': 7.161115646362305,
#   'for free': 6.299354076385498,
#   'for free shipping': 7.157605171203613,
#   'for iphone': 6.272572040557861,
#   'for it': 6.913965702056885,
#   'for looking': 5.799253940582275,
#   'for me': 5.803851127624512,
#   'for more': 5.546194076538086,
#   'for my': 6.362192153930664,
#   'for one': 6.707997798919678,
#   'for sale': 6.2393412590026855,
#   'for shipping': 6.475026607513428,
#   'for summer': 7.180483341217041,
#   'for the': 5.077009201049805,
#   'for this': 6.732268810272217,
#   'for you': 5.99194860458374,
#   'for your': 5.959319114685059,
#   'forever': 5.8461174964904785,
#   'forever 21': 6.012617588043213,
#   'forget': 7.13150691986084,
#   'formula': 6.661930561065674,
#   'foundation': 6.215961456298828,
#   'four': 6.687481880187988,
#   'fragrance': 6.525032997131348,
#   'frame': 6.9265289306640625,
#   'free': 2.892841100692749,
#   'free and': 6.637204647064209,
#   'free gift': 6.983761787414551,
#   'free home': 4.447412014007568,
#   'free people': 6.821269512176514,
#   'free pet': 6.312950134277344,
#   'free pet free': 6.543306827545166,
#   'free ship': 5.6589579582214355,
#   'free shipping': 3.582064628601074,
#   'free shipping brand': 6.96361780166626,
#   'free shipping bundle': 7.078322410583496,
#   'free shipping on': 7.175282001495361,
#   'free shipping price': 6.970727920532227,
#   'free to': 5.398550510406494,
#   'free to ask': 6.044130802154541,
#   'fresh': 6.553875923156738,
#   'friday': 6.943871974945068,
#   'friendly': 6.485870838165283,
#   'friendly home': 6.970992088317871,
#   'from': 3.5001723766326904,
#   'from my': 7.014759063720703,
#   'from smoke': 5.608234405517578,
#   'from smoke free': 5.874320030212402,
#   'from the': 5.615909576416016,
#   'front': 4.817841529846191,
#   'front and': 6.836403846740723,
#   'full': 4.7342610359191895,
#   'full size': 5.9685893058776855,
#   'fully': 6.682121276855469,
#   'fun': 6.12177038192749,
#   'funko': 6.903533458709717,
#   'funko pop': 7.1965837478637695,
#   'fur': 6.877678394317627,
#   'galaxy': 6.48847770690918,
#   'game': 5.828675270080566,
#   'games': 6.253171443939209,
#   'gap': 6.638530731201172,
#   'gel': 6.308443069458008,
#   'generation': 7.7176194190979,
#   'gently': 5.290199279785156,
#   'gently used': 5.683165073394775,
#   'gently worn': 6.910227298736572,
#   'genuine': 6.839643955230713,
#   'get': 4.549068450927734,
#   'getting': 6.816954612731934,
#   'gift': 5.067469120025635,
#   'gift for': 7.048746585845947,
#   'gifts': 6.986442565917969,
#   'girl': 5.735867977142334,
#   'girls': 5.759120464324951,
#   'give': 5.915594577789307,
#   'give you': 7.08748722076416,
#   'glass': 6.081654071807861,
#   'glasses': 7.198241233825684,
#   'glitter': 6.343811988830566,
#   'gloss': 6.465095520019531,
#   'glow': 6.607179164886475,
#   'glue': 6.914215564727783,
#   'go': 5.305727005004883,
#   'goes': 6.669527530670166,
#   'going': 6.654582977294922,
#   'gold': 4.595232009887695,
#   'golden': 7.172368049621582,
#   'gone': 6.996967792510986,
#   'good': 3.6930646896362305,
#   'good condition': 4.164233207702637,
#   'good condition no': 6.6910719871521,
#   'good condition size': 7.183094501495361,
#   'good for': 7.197909355163574,
#   'good shape': 7.0278239250183105,
#   'good used': 6.279962062835693,
#   'good used condition': 6.322855472564697,
#   'gorgeous': 5.643630504608154,
#   'got': 5.683675765991211,
#   'gray': 5.240176677703857,
#   'great': 3.342806100845337,
#   'great condition': 4.14553689956665,
#   'great condition no': 6.662318706512451,
#   'great condition size': 7.085114002227783,
#   'great deal': 7.041345119476318,
#   'great for': 5.361501216888428,
#   'great gift': 7.1756062507629395,
#   'great shape': 6.583037853240967,
#   'green': 4.845602989196777,
#   'grey': 5.066327095031738,
#   'grip': 7.311224937438965,
#   'guaranteed': 6.523679733276367,
#   'gym': 6.978953838348389,
#   'had': 6.073432445526123,
#   'hair': 5.757312297821045,
#   'half': 6.272046089172363,
#   'halloween': 6.464776515960693,
#   'halter': 7.175930500030518,
#   'hand': 5.711717128753662,
#   'handful': 6.729565620422363,
#   'handful of': 6.751397132873535,
#   'handful of times': 6.791450023651123,
#   'handle': 6.649394989013672,
#   'handles': 7.069240570068359,
#   'handmade': 6.289276599884033,
#   'hands': 6.939507961273193,
#   'happy': 5.722733020782471,
#   'happy shopping': 7.0456085205078125,
#   'happy to': 6.722118377685547,
#   'hard': 5.56344747543335,
#   'hard to': 6.091368675231934,
#   'hard to find': 6.361617565155029,
#   'hardly': 6.70414400100708,
#   'hardware': 6.599309921264648,
#   'has': 3.74932861328125,
#   'has been': 5.701712608337402,
#   'has never': 7.028383731842041,
#   'has never been': 7.067201614379883,
#   'has no': 7.226165771484375,
#   'has small': 7.191627502441406,
#   'has some': 6.382970333099365,
#   'has the': 7.173338413238525,
#   'hat': 6.283278465270996,
#   'have': 3.519834518432617,
#   'have any': 5.722884654998779,
#   'have any questions': 5.971795558929443,
#   'have been': 6.037145614624023,
#   'have never': 7.183748245239258,
#   'have no': 7.0593743324279785,
#   'have some': 6.99914026260376,
#   'have the': 6.2461042404174805,
#   'have to': 6.738115310668945,
#   'haven': 7.139922142028809,
#   'he': 7.117025375366211,
#   'head': 6.5887932777404785,
#   'headphones': 7.081860065460205,
#   'heart': 6.311855792999268,
#   'heat': 6.895657539367676,
#   'heavy': 6.726663112640381,
#   'heel': 6.432325839996338,
#   'heels': 6.745683193206787,
#   'height': 6.845921993255615,
#   'hello': 7.028663635253906,
#   'help': 6.217826843261719,
#   'helps': 6.731436252593994,
#   'hem': 6.863571643829346,
#   'her': 6.738743782043457,
#   'here': 5.880785942077637,
#   'high': 4.686168670654297,
#   'high quality': 5.542892932891846,
#   'high waisted': 7.177554130554199,
#   'highlight': 7.266902446746826,
#   'highlighter': 6.994258403778076,
#   'highly': 7.141175270080566,
#   'hold': 5.813856601715088,
#   'holder': 6.539007186889648,
#   'holds': 5.522690296173096,
#   'hole': 6.8373284339904785,
#   'holes': 5.595394611358643,
#   'holes or': 6.877678394317627,
#   'holiday': 6.689873695373535,
#   'holidays': 6.844058036804199,
#   'hollister': 6.426021575927734,
#   'home': 4.135961055755615,
#   'honey': 7.169139862060547,
#   'hood': 6.851301670074463,
#   'hoodie': 5.94766092300415,
#   'hot': 5.661452770233154,
#   'hot pink': 6.638530731201172,
#   'hours': 5.7658305168151855,
#   'house': 6.5909600257873535,
#   'how': 5.639712810516357,
#   'how to': 7.033998489379883,
#   'however': 6.614184856414795,
#   'htf': 7.030065059661865,
#   'id': 7.215644836425781,
#   'if': 3.922199010848999,
#   'if it': 7.000228404998779,
#   'if you': 4.350111961364746,
#   'if you are': 6.617892265319824,
#   'if you have': 5.630053997039795,
#   'if you like': 7.079794883728027,
#   'if you need': 7.124085903167725,
#   'if you want': 6.08024263381958,
#   'if you would': 6.976558685302734,
#   'ignored': 6.8384857177734375,
#   'imperfections': 6.910725116729736,
#   'imported': 7.054764747619629,
#   'in': 2.351541519165039,
#   'in black': 6.785942554473877,
#   'in box': 5.105411052703857,
#   'in color': 6.806808948516846,
#   'in excellent': 5.525177478790283,
#   'in excellent condition': 5.716832637786865,
#   'in good': 4.894561767578125,
#   'in good condition': 5.160897731781006,
#   'in great': 4.800738334655762,
#   'in great condition': 5.005450248718262,
#   'in great shape': 6.975230693817139,
#   'in like': 7.186039924621582,
#   'in my': 5.82968807220459,
#   'in my closet': 6.803226470947266,
#   'in one': 7.0765581130981445,
#   'in original': 6.3364973068237305,
#   'in package': 6.202020168304443,
#   'in packaging': 6.823319911956787,
#   'in perfect': 6.061438083648682,
#   'in perfect condition': 6.1875457763671875,
#   'in picture': 6.830644130706787,
#   'in pictures': 7.1844024658203125,
#   'in size': 6.455419540405273,
#   'in the': 4.292740821838379,
#   'in the back': 6.791670799255371,
#   'in the box': 7.009525775909424,
#   ...}}

# %%
# %%time
top_tfidf_word = []
top_tfidf_value = []
for i in range(len(list(train_df["item_description"].values))):
    for word in top_n_tfidf.index:
        if word in train_df["item_description"][i]:
            #print("YES, #", i, ":", word, "is in", train_df["item_description"][i])
            chosen_word = word
            chosen_tfidf = float(top_n_tfidf.loc[word])
            #print(chosen_word, chosen_tfidf)
            #print(type(chosen_word), type(chosen_tfidf))
            top_tfidf_word.insert(i, chosen_word)
            top_tfidf_value.insert(i, chosen_tfidf)
            break
        else:
            chosen_word = "None"
            chosen_tfidf = 0.0
            top_tfidf_word.insert(i, chosen_word)
            top_tfidf_value.insert(i, chosen_tfidf)
            continue
    #if i > 30:
        #break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# KeyboardInterrupt:

# %%
# %%time
top_tfidf_word_2 = []
top_tfidf_value_2 = []
for i in range(len(list(test_df["item_description"].values))):
    for word in top_n_tfidf.index:
        if word in test_df["item_description"][i]:
            #print("YES, #", i, ":", word, "is in", train_df["item_description"][i])
            chosen_word = word
            chosen_tfidf = float(top_n_tfidf.loc[word])
            #print(chosen_word, chosen_tfidf)
            #print(type(chosen_word), type(chosen_tfidf))
            top_tfidf_word_2.insert(i, chosen_word)
            top_tfidf_value_2.insert(i, chosen_tfidf)
            break
        else:
            chosen_word = "None"
            chosen_tfidf = 0.0
            top_tfidf_word_2.insert(i, chosen_word)
            top_tfidf_value_2.insert(i, chosen_tfidf)
            continue

# %%
train_df["top_tfidf_word"] = top_tfidf_word
train_df["top_tfidf_value"] = top_tfidf_value

test_df["top_tfidf_word"] = top_tfidf_word_2
test_df["top_tfidf_value"] = top_tfidf_value_2

# %% [markdown]
# view the data again

# %%
train_df.head()

# %%
test_df.head()

# %% [markdown]
# checking the shape again

# %%
print('Train shape: {}\nTest shape: {}'.format(train_df.shape, test_df.shape))

# %%
train_df.to_csv("data/train_df.csv", index=False)
test_df.to_csv("data/test_df.csv", index=False)
