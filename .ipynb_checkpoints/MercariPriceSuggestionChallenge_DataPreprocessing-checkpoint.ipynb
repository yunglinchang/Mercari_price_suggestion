# %% [markdown]
# # [Mercari Price Suggestion Challenge](https://www.kaggle.com/c/mercari-price-suggestion-challenge)
# Can you automatically suggest product prices to online sellers?

# %% [markdown]
# # Import packages
# - pandas
# - numpy
# - TfidfVectorizer

# %%
import pandas as pd #data processing
import numpy as np #linear algebra
from sklearn.feature_extraction.text import TfidfVectorizer #to calculate Tf-idf

# %% [markdown]
# # Import data
# load train and test data, split by tab because of the tsv format.

# %%
# %%time
train_df = pd.read_csv("data/train.tsv", delimiter="\t", low_memory= True)
test_df = pd.read_csv("data/test.tsv", delimiter="\t", low_memory= True)
# Out:
# CPU times: user 9.53 ms, sys: 4.12 ms, total: 13.6 ms
# Wall time: 13 ms

# %%
train_df.head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# 1         0  This keyboard is in great condition and works ...
# 2         1  Adorable top with a hint of lace and a key hol...
# 3         1  New with tags. Leather horses. Retail for [rm]...
# 4         0          Complete with certificate of authenticity

# %%
train_df.columns
# Out:
# Index(['train_id', 'name', 'item_condition_id', 'category_name', 'brand_name',
#        'price', 'shipping', 'item_description'],
#       dtype='object')

# %% [markdown]
# # data preprocessing

# %% [markdown]
# ### converting column types

# %%
print(train_df.dtypes)
print("------------")
print(test_df.dtypes)
# Out:
# train_id               int64
# name                  object
# item_condition_id      int64
# category_name         object
# brand_name            object
# price                float64
# shipping               int64
# item_description      object
# dtype: object
# ------------
# test_id               int64
# name                 object
# item_condition_id     int64
# category_name        object
# brand_name           object
# shipping              int64
# item_description     object
# dtype: object

# %% [markdown]
# converting column data types to minimize memory

# %%
def col_type_conversion(data):
    data["item_condition_id"] = data["item_condition_id"].astype("int32")
    data["shipping"] = data["shipping"].astype("int8")

col_type_conversion(train_df)
col_type_conversion(test_df)

# %%
print(train_df.dtypes)
print("------------")
print(test_df.dtypes)
# Out:
# train_id               int64
# name                  object
# item_condition_id      int32
# category_name         object
# brand_name            object
# price                float64
# shipping                int8
# item_description      object
# dtype: object
# ------------
# test_id               int64
# name                 object
# item_condition_id     int32
# category_name        object
# brand_name           object
# shipping               int8
# item_description     object
# dtype: object

# %% [markdown]
# do a little exploring on discriptive statistics

# %%
print("train_df shape: {}\ntest_df shape: {}".format(train_df.shape, test_df.shape))
# Out:
# train_df shape: (500, 8)
# test_df shape: (500, 7)

# %%
pd.set_option("float_format", "{:f}".format)
train_df.describe()
# Out:
#         train_id  item_condition_id      price   shipping
# count 500.000000         500.000000 500.000000 500.000000
# mean  249.500000           1.908000  28.632000   0.440000
# std   144.481833           0.925878  47.412112   0.496884
# min     0.000000           1.000000   3.000000   0.000000
# 25%   124.750000           1.000000  10.000000   0.000000
# 50%   249.500000           2.000000  16.000000   0.000000
# 75%   374.250000           3.000000  31.000000   1.000000
# max   499.000000           5.000000 650.000000   1.000000

# %% [markdown]
# checking individual values

# %%
train_df.apply(lambda x: x.nunique())
# Out:
# train_id             500
# name                 499
# item_condition_id      5
# category_name        190
# brand_name           151
# price                 83
# shipping               2
# item_description     470
# dtype: int64

# %% [markdown]
# ### checking missing values

# %%
print(train_df.isnull().sum()[train_df.isnull().sum() != 0])
print("------------")
print(test_df.isnull().sum()[test_df.isnull().sum() != 0])
# Out:
# category_name      3
# brand_name       205
# dtype: int64
# ------------
# category_name      1
# brand_name       206
# dtype: int64

# %% [markdown]
# found missing values in category_name, brand_name, and item_discription
# - Fill products with no brand name with 'NoBrand'
# - Fill products with no category name with 'No/No/No'
# - Fill products with no item descriptions with 'No description yet' (same as the first data)

# %%
test_df["item_description"].isnull().sum() != 0
# Out:
# False

# %%
def input_missing_values(data):
    if data["brand_name"].isnull().sum() != 0:
        data["brand_name"] = data["brand_name"].fillna("NoBrand")
    if data["category_name"].isnull().sum() != 0:
        data["category_name"] = data["category_name"].fillna("No/No/No")
    if data["item_description"].isnull().sum() != 0:
        data["item_description"] = data["item_description"].fillna("No description yet")
        
input_missing_values(train_df)
input_missing_values(test_df)

# %%
print(train_df.isnull().sum()[train_df.isnull().sum() != 0])
print("------------")
print(test_df.isnull().sum()[test_df.isnull().sum() != 0])
# Out:
# Series([], dtype: int64)
# ------------
# Series([], dtype: int64)

# %% [markdown]
# # feature engineering

# %% [markdown]
# extracting data from category_name and item_discription

# %% [markdown]
# split category_name into:
# - general_category
# - subcategory_1
# - subcategory_2

# %%
def split_category_name(data):
    split_category_name = data["category_name"].str.split("/", n = 2, expand = True)
    data["general_category"] = split_category_name[0]
    data["subcategory_1"] = split_category_name[1]
    data["subcategory_2"] = split_category_name[2]
    return data[["general_category", "subcategory_1", "subcategory_2"]].head()

split_category_name(train_df)
split_category_name(test_df)
# Out:
#          general_category    subcategory_1            subcategory_2
# 0                   Women          Jewelry                    Rings
# 1                   Other  Office supplies        Shipping Supplies
# 2  Vintage & Collectibles  Bags and Purses                  Handbag
# 3                   Women         Sweaters                 Cardigan
# 4                   Other            Books  Religion & Spirituality

# %% [markdown]
# dealing with item_description:
# <br>[Extensive Text Data Feature Engineering](https://www.kaggle.com/shivamb/extensive-text-data-feature-engineering)
# - character length
# - word count
# - word density
# - puncutation count

# %%
def text_data_fe(data):
    data["char_count"] = data["item_description"].apply(len)
    data["word_count"] = data["item_description"].apply(lambda x: len(x.split()))
    data["word_density"] = data["char_count"] / (data["word_count"]+1)
    return data[["char_count", "word_count", "word_density"]].head()

text_data_fe(train_df)
text_data_fe(test_df)
# Out:
#    char_count  word_count  word_density
# 0           6           2      2.000000
# 1         251          38      6.435897
# 2          55          11      4.583333
# 3          67          10      6.090909
# 4         167          29      5.566667

# %% [markdown]
# [CountVectorizer, TfidfVectorizer, Predict Comments](https://www.kaggle.com/adamschroeder/countvectorizer-tfidfvectorizer-predict-comments)
# <br>[Using TfidfVectorizer output to create columns in a pandas df](https://www.reddit.com/r/learnpython/comments/7aduzh/using_tfidfvectorizer_output_to_create_columns_in/)
# <br>[Check if multiple strings exist in another string](https://stackoverflow.com/questions/3389574/check-if-multiple-strings-exist-in-another-string)
# - top tfidf word
# - top tfidf value

# %%
vectorizer = TfidfVectorizer(min_df=3, max_features=2500, dtype=np.float32, 
                             strip_accents="unicode", analyzer="word", ngram_range=(1, 3), 
                             stop_words={"english", "rm", "co"})

# %%
# %%time
description_text = list(train_df["item_description"].values)
tfidf_matrix = vectorizer.fit_transform(description_text)
# Out:
# CPU times: user 63.7 ms, sys: 4.79 ms, total: 68.5 ms
# Wall time: 67.6 ms

# %%
tfidf_matrix
# Out:
# <500x1110 sparse matrix of type '<class 'numpy.float32'>'
# 	with 9363 stored elements in Compressed Sparse Row format>

# %%
tfidf_matrix.shape
# Out:
# (500, 1110)

# %% [markdown]
# the learned corpus vocabulary

# %%
vectorizer.vocabulary_
# Out:
# {'no': 621,
#  'description': 244,
#  'yet': 1094,
#  'no description': 623,
#  'description yet': 245,
#  'no description yet': 624,
#  'this': 971,
#  'is': 460,
#  'in': 433,
#  'great': 384,
#  'condition': 214,
#  'and': 47,
#  'works': 1084,
#  'like': 511,
#  'it': 468,
#  'out': 686,
#  'of': 645,
#  'the': 948,
#  'box': 140,
#  'all': 37,
#  'are': 68,
#  'work': 1083,
#  'perfectly': 715,
#  'via': 1030,
#  'on': 657,
#  'your': 1105,
#  'is in': 462,
#  'in great': 439,
#  'great condition': 385,
#  'condition and': 215,
#  'out of': 690,
#  'of the': 649,
#  'the box': 950,
#  'all of': 39,
#  'on your': 665,
#  'in great condition': 440,
#  'adorable': 31,
#  'top': 996,
#  'with': 1069,
#  'lace': 492,
#  'key': 484,
#  'back': 84,
#  'pink': 729,
#  'also': 40,
#  'have': 403,
#  'available': 82,
#  'white': 1057,
#  'top with': 998,
#  'in the': 446,
#  'the back': 949,
#  'also have': 42,
#  'in the back': 447,
#  'new': 603,
#  'tags': 929,
#  'leather': 497,
#  'retail': 790,
#  'for': 327,
#  'each': 273,
#  'stand': 902,
#  'about': 22,
#  'high': 415,
#  'they': 967,
#  'being': 113,
#  'sold': 894,
#  'as': 73,
#  'pair': 699,
#  'any': 61,
#  'questions': 770,
#  'please': 732,
#  'ask': 76,
#  'free': 346,
#  'shipping': 839,
#  'just': 482,
#  'got': 382,
#  'storage': 909,
#  'new with': 613,
#  'with tags': 1074,
#  'for each': 333,
#  'they are': 968,
#  'any questions': 62,
#  'questions please': 771,
#  'please ask': 733,
#  'free shipping': 349,
#  'new with tags': 615,
#  'any questions please': 63,
#  'questions please ask': 772,
#  'complete': 213,
#  'banana': 89,
#  'republic': 787,
#  'bottoms': 136,
#  'skirt': 874,
#  'matching': 554,
#  'suit': 918,
#  'banana republic': 90,
#  'with matching': 1072,
#  'size': 860,
#  'small': 882,
#  'but': 165,
#  'straps': 912,
#  'slightly': 879,
#  'to': 982,
#  'fit': 316,
#  'xs': 1092,
#  'that': 947,
#  'perfect': 711,
#  'size small': 867,
#  'small but': 883,
#  'perfect condition': 712,
#  'size small but': 868,
#  'you': 1096,
#  'get': 370,
#  'three': 975,
#  'pairs': 700,
#  'shorts': 847,
#  'medium': 567,
#  'girls': 374,
#  'two': 1008,
#  'bra': 143,
#  'boy': 141,
#  'spandex': 897,
#  'sets': 829,
#  'items': 475,
#  'total': 999,
#  'store': 910,
#  'can': 173,
#  'take': 931,
#  'than': 941,
#  'price': 749,
#  'one': 667,
#  'item': 473,
#  'at': 79,
#  'you get': 1099,
#  'all items': 38,
#  'and you': 59,
#  'you can': 1098,
#  'the price': 955,
#  'at the': 80,
#  'plus': 737,
#  'green': 389,
#  'his': 418,
#  'pants': 702,
#  'after': 32,
#  'picture': 724,
#  'were': 1052,
#  'very': 1029,
#  'so': 890,
#  'hand': 394,
#  'washed': 1044,
#  'them': 961,
#  'he': 408,
#  'has': 401,
#  'body': 129,
#  'head': 409,
#  'hands': 395,
#  'before': 111,
#  'too': 993,
#  'tall': 934,
#  'chips': 188,
#  'or': 675,
#  'cracks': 229,
#  'minor': 574,
#  'few': 309,
#  'the picture': 954,
#  '25': 13,
#  'oz': 693,
#  'full': 364,
#  'full size': 365,
#  'vs': 1036,
#  'fresh': 352,
#  'clean': 191,
#  'cool': 223,
#  'sweet': 926,
#  'vs pink': 1037,
#  'xl': 1091,
#  'authentic': 81,
#  'suede': 917,
#  'boots': 132,
#  'if': 427,
#  'sizes': 871,
#  'love': 537,
#  'wearing': 1049,
#  'thick': 969,
#  'socks': 892,
#  'during': 270,
#  'winter': 1068,
#  'be': 101,
#  'well': 1051,
#  'last': 496,
#  'condition size': 219,
#  'if you': 428,
#  'you are': 1097,
#  'during the': 271,
#  'perfect for': 713,
#  'for you': 343,
#  'if you are': 429,
#  'brand': 145,
#  'travel': 1003,
#  'contains': 222,
#  '12': 4,
#  'blush': 128,
#  'lip': 516,
#  'brand new': 146,
#  'travel size': 1004,
#  'glitter': 375,
#  'and one': 53,
#  'color': 198,
#  'retails': 791,
#  'baby': 83,
#  'tan': 936,
#  'made': 542,
#  'fabric': 293,
#  'over': 691,
#  'unique': 1015,
#  'weight': 1050,
#  'across': 25,
#  'double': 263,
#  'design': 246,
#  'shirt': 844,
#  'new in': 606,
#  'in box': 434,
#  'size medium': 866,
#  'retails for': 792,
#  'for the': 342,
#  'made of': 545,
#  'back and': 85,
#  'brand new in': 148,
#  'new in box': 607,
#  'by': 171,
#  'faced': 294,
#  'still': 906,
#  'original': 678,
#  'part': 703,
#  'christmas': 189,
#  'collection': 197,
#  'pretty': 748,
#  'eye': 289,
#  'colors': 202,
#  'sized': 870,
#  'better': 117,
#  'mascara': 553,
#  'never': 596,
#  'even': 281,
#  'shape': 832,
#  'includes': 452,
#  'day': 240,
#  'priority': 755,
#  'too faced': 995,
#  'still in': 907,
#  'original box': 679,
#  'part of': 704,
#  'better than': 118,
#  'dress': 265,
#  'up': 1019,
#  'down': 264,
#  '100': 1,
#  'polyester': 742,
#  'once': 666,
#  'purchased': 764,
#  'from': 355,
#  'people': 709,
#  'dry': 266,
#  'worn': 1085,
#  'excellent': 285,
#  'worn once': 1087,
#  'excellent condition': 286,
#  'nwt': 643,
#  'victoria': 1032,
#  'secret': 816,
#  'victoria secret': 1033,
#  'offers': 652,
#  'lowest': 539,
#  'll': 525,
#  'phone': 719,
#  'was': 1042,
#  'opened': 674,
#  'under': 1011,
#  'now': 639,
#  'been': 108,
#  'used': 1023,
#  'check': 183,
#  'my': 583,
#  'feedback': 305,
#  'charger': 182,
#  'included': 451,
#  'but has': 166,
#  'like new': 512,
#  'new still': 612,
#  'in perfect': 444,
#  'used condition': 1024,
#  'only': 671,
#  'new never': 609,
#  'never used': 600,
#  'brand new never': 149,
#  'new never used': 610,
#  'update': 1020,
#  'listings': 522,
#  'easier': 274,
#  'ship': 835,
#  'days': 241,
#  'purchase': 763,
#  'forever': 344,
#  '21': 10,
#  'brandy': 151,
#  'melville': 569,
#  'baseball': 94,
#  'tee': 940,
#  'never worn': 601,
#  'my listings': 585,
#  'ship the': 836,
#  'but it': 167,
#  'brandy melville': 152,
#  'lot': 534,
#  'life': 505,
#  'of life': 646,
#  'iphone': 457,
#  '6s': 20,
#  'iphone plus': 459,
#  '6s plus': 21,
#  'time': 979,
#  'one time': 670,
#  'beautiful': 104,
#  'ties': 978,
#  'cream': 231,
#  'liner': 515,
#  'bottom': 134,
#  'jeans': 479,
#  'see': 818,
#  'tag': 928,
#  'belt': 115,
#  'favorite': 303,
#  'please see': 736,
#  'other': 681,
#  'my other': 586,
#  'logo': 526,
#  'band': 91,
#  'unused': 1018,
#  'beauty': 105,
#  'pumpkin': 762,
#  'big': 119,
#  'dog': 258,
#  'cute': 236,
#  'us': 1021,
#  'soft': 893,
#  'real': 782,
#  'gorgeous': 381,
#  'long': 527,
#  'candy': 176,
#  'present': 747,
#  'girl': 373,
#  'everything': 284,
#  'kawaii': 483,
#  'gift': 372,
#  'unicorn': 1014,
#  'kitty': 487,
#  'wild': 1059,
#  'fits': 317,
#  'super': 920,
#  'leggings': 500,
#  'waist': 1038,
#  'elastic': 278,
#  'one size': 668,
#  'size fits': 863,
#  'super soft': 922,
#  'one size fits': 669,
#  'some': 895,
#  'light': 507,
#  'scratches': 812,
#  'hardware': 400,
#  'use': 1022,
#  'comes': 207,
#  'comes with': 208,
#  'wear': 1048,
#  'which': 1056,
#  'to the': 990,
#  'can be': 174,
#  'cord': 224,
#  'pack': 694,
#  'games': 367,
#  'doesn': 257,
#  'the top': 959,
#  '34': 16,
#  'will': 1060,
#  'bundle': 156,
#  'save': 808,
#  'feel': 306,
#  'will bundle': 1063,
#  'bundle to': 158,
#  'to save': 987,
#  'save on': 809,
#  'on shipping': 662,
#  'you have': 1100,
#  'have any': 404,
#  'feel free': 307,
#  'free to': 350,
#  'to ask': 984,
#  'will bundle to': 1064,
#  'bundle to save': 159,
#  'to save on': 988,
#  'save on shipping': 810,
#  'if you have': 430,
#  'you have any': 1101,
#  'have any questions': 405,
#  'feel free to': 308,
#  'free to ask': 351,
#  'kylie': 490,
#  'happy': 396,
#  'matte': 557,
#  'mini': 573,
#  'lipstick': 517,
#  'jenner': 480,
#  'kit': 486,
#  'firm': 311,
#  'not': 633,
#  'takes': 933,
#  'usps': 1027,
#  'within': 1078,
#  '24': 12,
#  'hours': 425,
#  'kylie jenner': 491,
#  'never opened': 599,
#  'price is': 751,
#  'is firm': 461,
#  'via usps': 1031,
#  'ship within': 837,
#  'price is firm': 752,
#  'looks': 531,
#  'ready': 781,
#  'shipped': 838,
#  'print': 754,
#  'comfy': 210,
#  'quality': 768,
#  'where': 1055,
#  'every': 283,
#  'lightly': 510,
#  'lined': 514,
#  'ships': 843,
#  'same': 805,
#  'seller': 820,
#  'new and': 604,
#  'and is': 52,
#  'secret pink': 817,
#  '100 authentic': 2,
#  'same day': 806,
#  'brand new and': 147,
#  'victoria secret pink': 1034,
#  'will be': 1061,
#  'fast': 299,
#  'find': 310,
#  'more': 578,
#  'sell': 819,
#  'make': 547,
#  'bundles': 161,
#  'fast free': 300,
#  'shipping you': 842,
#  'items in': 476,
#  'in my': 441,
#  'listings for': 523,
#  'is new': 464,
#  'for free': 335,
#  'fast free shipping': 301,
#  'for free shipping': 336,
#  'bought': 137,
#  'return': 793,
#  'these': 965,
#  'things': 970,
#  'buy': 169,
#  'after you': 33,
#  'too big': 994,
#  'for my': 339,
#  'black': 123,
#  'gray': 383,
#  'inside': 454,
#  'warm': 1041,
#  'runs': 802,
#  'true': 1007,
#  'and in': 51,
#  'new condition': 605,
#  'slime': 880,
#  'approximately': 66,
#  'an': 46,
#  'air': 36,
#  'easy': 276,
#  'bath': 96,
#  'it is': 470,
#  'this item': 973,
#  'bath and': 97,
#  'and body': 49,
#  'body works': 130,
#  'bath and body': 98,
#  'and body works': 50,
#  'off': 651,
#  'shoulder': 849,
#  'crop': 234,
#  'sleeves': 878,
#  'actual': 26,
#  'navy': 591,
#  'blue': 126,
#  'stripes': 914,
#  'navy blue': 592,
#  'blue and': 127,
#  'let': 502,
#  'me': 561,
#  'know': 488,
#  'want': 1039,
#  'pictures': 727,
#  'sure': 924,
#  'discount': 251,
#  'usually': 1028,
#  'post': 744,
#  'office': 655,
#  'issues': 467,
#  'let me': 503,
#  'me know': 563,
#  'know if': 489,
#  'you want': 1102,
#  'are not': 69,
#  'the same': 956,
#  'post office': 745,
#  'as you': 75,
#  'is my': 463,
#  'let me know': 504,
#  'me know if': 564,
#  'if you want': 431,
#  'the same day': 957,
#  'lash': 494,
#  'quickly': 773,
#  'lashes': 495,
#  'package': 695,
#  'it will': 472,
#  'in package': 443,
#  'never been': 597,
#  'new in package': 608,
#  'sz': 927,
#  'large': 493,
#  'color black': 199,
#  'shoes': 846,
#  'kids': 485,
#  'red': 784,
#  'purple': 766,
#  'yellow': 1093,
#  'different': 250,
#  'unisex': 1016,
#  'boys': 142,
#  '10': 0,
#  'in one': 442,
#  'white and': 1058,
#  'vintage': 1035,
#  'hot': 424,
#  'bundle for': 157,
#  'colored': 201,
#  'message': 571,
#  'message me': 572,
#  '2017': 9,
#  'rae': 774,
#  'dunn': 269,
#  'another': 60,
#  'someone': 896,
#  'special': 898,
#  'we': 1047,
#  'care': 177,
#  'order': 677,
#  'when': 1054,
#  'help': 413,
#  'rae dunn': 775,
#  'necklace': 594,
#  'stains': 900,
#  'tears': 939,
#  'condition no': 217,
#  'no stains': 630,
#  'stains or': 901,
#  'easy to': 277,
#  'to use': 991,
#  'great condition no': 386,
#  'diamond': 248,
#  'ring': 795,
#  'most': 579,
#  'this is': 972,
#  'bag': 88,
#  'hard': 397,
#  'background': 86,
#  'always': 43,
#  'bundling': 162,
#  'with tag': 1073,
#  'hard to': 398,
#  'to find': 985,
#  'made in': 543,
#  'check out': 184,
#  'out my': 687,
#  'other listings': 683,
#  'brand new with': 150,
#  'new with tag': 614,
#  'hard to find': 399,
#  'check out my': 185,
#  'out my other': 689,
#  'my other listings': 587,
#  'distressed': 252,
#  'size xs': 869,
#  'of my': 648,
#  'men': 570,
#  'good': 377,
#  'mark': 551,
#  'sleeve': 876,
#  'in good': 437,
#  'good condition': 378,
#  'condition minor': 216,
#  'mark on': 552,
#  'in good condition': 438,
#  'closure': 194,
#  '16': 7,
#  'inches': 449,
#  'length': 501,
#  'rarely': 776,
#  'flaws': 322,
#  'selling': 821,
#  'don': 260,
#  'cotton': 226,
#  'no flaws': 625,
#  'condition no flaws': 218,
#  'armour': 70,
#  'zip': 1107,
#  'jacket': 478,
#  'med': 566,
#  'under armour': 1012,
#  'size med': 865,
#  'protection': 759,
#  'extremely': 288,
#  'ignored': 432,
#  'factory': 295,
#  'sealed': 815,
#  'packaging': 696,
#  'page': 697,
#  'cases': 179,
#  'tracking': 1001,
#  'offers will': 653,
#  'be ignored': 102,
#  'factory sealed': 296,
#  'offers will be': 654,
#  'will be ignored': 1062,
#  'overall': 692,
#  'signs': 857,
#  'signs of': 858,
#  'of wear': 650,
#  'type': 1009,
#  'chain': 180,
#  'china': 187,
#  '15': 6,
#  'pictured': 726,
#  'sample': 807,
#  'highly': 417,
#  'nib': 619,
#  'essential': 279,
#  'guaranteed': 391,
#  'safe': 803,
#  'home': 422,
#  'ft': 363,
#  'scent': 811,
#  'throw': 977,
#  'addition': 28,
#  'room': 798,
#  'business': 164,
#  'compatible': 212,
#  'bed': 107,
#  'listed': 520,
#  'profile': 758,
#  'per': 710,
#  'regular': 786,
#  'again': 34,
#  'our': 685,
#  'addition to': 29,
#  'in your': 448,
#  'high quality': 416,
#  'best': 116,
#  'old': 656,
#  'extra': 287,
#  'responsible': 788,
#  'cracks or': 230,
#  'not responsible': 636,
#  'responsible for': 789,
#  'not responsible for': 637,
#  'hold': 419,
#  'do': 253,
#  'these are': 966,
#  'do not': 254,
#  'both': 133,
#  'come': 204,
#  'then': 962,
#  'burgundy': 163,
#  'separately': 824,
#  'new never worn': 611,
#  'look': 529,
#  'charged': 181,
#  'with the': 1076,
#  'sent': 823,
#  'brown': 153,
#  'sheer': 833,
#  'flower': 324,
#  'front': 362,
#  'without': 1079,
#  'shade': 830,
#  'cosmetics': 225,
#  'looking': 530,
#  'through': 976,
#  'above': 24,
#  'new without': 616,
#  'maybelline': 560,
#  'eyebrows': 291,
#  'need': 595,
#  'create': 233,
#  'follow': 326,
#  'natural': 589,
#  'line': 513,
#  'features': 304,
#  'eyebrow': 290,
#  'powder': 746,
#  'brush': 155,
#  'have the': 407,
#  'natural and': 590,
#  'used to': 1026,
#  'set': 827,
#  'flat': 321,
#  'fitted': 318,
#  'trim': 1006,
#  'from victoria': 360,
#  'light pink': 509,
#  'from victoria secret': 361,
#  'dvd': 272,
#  'include': 450,
#  'rise': 797,
#  'set of': 828,
#  'and the': 56,
#  'condition worn': 220,
#  'worn for': 1086,
#  'good used': 379,
#  'good used condition': 380,
#  'holes': 421,
#  'taken': 932,
#  '11': 3,
#  'spring': 899,
#  'summer': 919,
#  'fall': 298,
#  'great shape': 388,
#  'size 11': 862,
#  'for spring': 341,
#  'perfect for spring': 714,
#  'show': 850,
#  'gently': 368,
#  'lots': 535,
#  'left': 498,
#  'wash': 1043,
#  'wore': 1082,
#  'lots of': 536,
#  'life left': 506,
#  'no holes': 629,
#  'of life left': 647,
#  'shows': 853,
#  'how': 426,
#  'shades': 831,
#  'their': 960,
#  'and they': 57,
#  'me for': 562,
#  'it was': 471,
#  'it also': 469,
#  'bling': 125,
#  'case': 178,
#  'many': 550,
#  'stones': 908,
#  'missing': 576,
#  'barely': 92,
#  'noticeable': 638,
#  'strap': 911,
#  'neck': 593,
#  'super cute': 921,
#  'rose': 799,
#  'gold': 376,
#  'signature': 856,
#  'no box': 622,
#  'pilling': 728,
#  '22': 11,
#  'inseam': 453,
#  'not noticeable': 635,
#  'what': 1053,
#  'cover': 228,
#  'rips': 796,
#  'in perfect condition': 445,
#  '13': 5,
#  'paid': 698,
#  'comment': 211,
#  'lower': 538,
#  'prices': 753,
#  'on the': 663,
#  'does': 255,
#  'zipper': 1109,
#  'pull': 761,
#  'smoke': 884,
#  'on back': 658,
#  'smoke free': 887,
#  'free home': 347,
#  'smoke free home': 888,
#  'boutique': 138,
#  'floral': 323,
#  'material': 555,
#  'boot': 131,
#  'great for': 387,
#  're': 778,
#  'am': 44,
#  'combine': 203,
#  'deal': 242,
#  'closet': 193,
#  'there': 963,
#  'so please': 891,
#  'my closet': 584,
#  'out my closet': 688,
#  'fun': 366,
#  'women': 1080,
#  'loose': 533,
#  'women size': 1081,
#  'brown leather': 154,
#  'bit': 121,
#  'product': 757,
#  'hoodie': 423,
#  'etc': 280,
#  'zip up': 1108,
#  'gently used': 369,
#  'size large': 864,
#  'sweater': 925,
#  'sleeved': 877,
#  'dark': 238,
#  'didn': 249,
#  'would': 1089,
#  'tiny': 981,
#  'skin': 872,
#  'comfortable': 209,
#  'clothes': 195,
#  'around': 71,
#  'pattern': 705,
#  'had': 392,
#  'add': 27,
#  'pay': 706,
#  'bundled': 160,
#  'from my': 356,
#  'pay shipping': 707,
#  'from my closet': 357,
#  'miss': 575,
#  'style': 915,
#  'name': 588,
#  'skinny': 873,
#  '32': 15,
#  'pic': 722,
#  'pocket': 738,
#  'its': 477,
#  'way': 1046,
#  'but not': 168,
#  'money': 577,
#  'will fit': 1065,
#  'the item': 952,
#  'item is': 474,
#  'is not': 465,
#  'you will': 1103,
#  'size 10': 861,
#  'wristlet': 1090,
#  'tone': 992,
#  'silver': 859,
#  'making': 549,
#  'be used': 103,
#  'can be used': 175,
#  'pop': 743,
#  'such': 916,
#  'could': 227,
#  'adjustable': 30,
#  'screen': 813,
#  'shield': 834,
#  'have been': 406,
#  'to any': 983,
#  'orange': 676,
#  'background with': 87,
#  'purse': 767,
#  'with box': 1071,
#  'stickers': 905,
#  'with all': 1070,
#  'little': 524,
#  'polka': 740,
#  'dot': 262,
#  'getting': 371,
#  'easily': 275,
#  'listing': 521,
#  'thanks': 944,
#  'flowers': 325,
#  'polka dot': 741,
#  'other items': 682,
#  'bow': 139,
#  'detail': 247,
#  'sleep': 875,
#  'been worn': 110,
#  'lululemon': 541,
#  'around the': 72,
#  'as pictured': 74,
#  'also has': 41,
#  '5c': 18,
#  'next': 618,
#  'iphone 5c': 458,
#  'will ship': 1067,
#  'ever': 282,
#  'york': 1095,
#  'base': 93,
#  'provide': 760,
#  'new york': 617,
#  'nike': 620,
#  'pet': 716,
#  'smoke and': 885,
#  'and pet': 54,
#  'pet free': 717,
#  'smoke and pet': 886,
#  'and pet free': 55,
#  'pet free home': 718,
#  'deep': 243,
#  'aqua': 67,
#  'and white': 58,
#  'tall and': 935,
#  'unless': 1017,
#  'otherwise': 684,
#  'rate': 777,
#  'because': 106,
#  'please don': 734,
#  'bracelet': 144,
#  'batman': 99,
#  'four': 345,
#  'read': 779,
#  'am not': 45,
#  'does not': 256,
#  'maternity': 556,
#  'pro': 756,
#  'cleanser': 192,
#  'zara': 1106,
#  'nude': 640,
#  'liquid': 518,
#  'receive': 783,
#  'picture is': 725,
#  'will receive': 1066,
#  'been used': 109,
#  'never been used': 598,
#  'times': 980,
#  'the size': 958,
#  'used no': 1025,
#  'cable': 172,
#  '5s': 19,
#  'ipad': 456,
#  'apple': 64,
#  'watch': 1045,
#  'superman': 923,
#  'hello': 411,
#  'thank': 942,
#  'the original': 953,
#  'want to': 1040,
#  'hello kitty': 412,
#  'mail': 546,
#  'first': 312,
#  'trades': 1002,
#  'holds': 420,
#  'number': 641,
#  'question': 769,
#  'right': 794,
#  'price firm': 750,
#  'don ask': 261,
#  'ask me': 78,
#  'no trades': 631,
#  'no holds': 628,
#  'thank you': 943,
#  'for apple': 331,
#  'apple iphone': 65,
#  'not included': 634,
#  'for apple iphone': 332,
#  'halloween': 393,
#  'here': 414,
#  'serve': 826,
#  'sale': 804,
#  'understand': 1013,
#  'bio': 120,
#  'much': 580,
#  'purchasing': 765,
#  'pink logo': 730,
#  'ask any': 77,
#  'first come': 313,
#  'come first': 205,
#  'first serve': 315,
#  'for sale': 340,
#  'to rate': 986,
#  'please read': 735,
#  'read my': 780,
#  'for more': 338,
#  'for looking': 337,
#  'first come first': 314,
#  'come first serve': 206,
#  'only worn': 672,
#  'only worn once': 673,
#  'tank': 937,
#  'tank top': 938,
#  'jordan': 481,
#  'run': 801,
#  'should': 848,
#  'there are': 964,
#  ...}

# %% [markdown]
# create a dictionary mapping the tokens to the tfidf values

# %%
tfidf = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))
tfidf_df = pd.DataFrame(columns=["description_text_tfidf"]).from_dict(dict(tfidf), orient='index')
tfidf_df.columns = ["description_text_tfidf"]

# %%
tfidf_df.shape
# Out:
# (1110, 1)

# %%
tfidf_df.to_dict()
# Out:
# {'description_text_tfidf': {'10': 4.326234340667725,
#   '100': 4.272167205810547,
#   '100 authentic': 5.13716459274292,
#   '11': 5.13716459274292,
#   '12': 4.818710803985596,
#   '13': 5.8303117752075195,
#   '15': 5.607168197631836,
#   '16': 5.607168197631836,
#   '20': 5.607168197631836,
#   '2017': 5.8303117752075195,
#   '21': 5.424846649169922,
#   '22': 5.8303117752075195,
#   '24': 5.424846649169922,
#   '25': 5.270695686340332,
#   '2x': 5.8303117752075195,
#   '32': 5.607168197631836,
#   '34': 5.8303117752075195,
#   '3rd': 5.607168197631836,
#   '5c': 5.424846649169922,
#   '5s': 5.8303117752075195,
#   '6s': 5.607168197631836,
#   '6s plus': 5.607168197631836,
#   'about': 4.508555889129639,
#   'about the': 5.8303117752075195,
#   'above': 5.8303117752075195,
#   'across': 5.424846649169922,
#   'actual': 5.8303117752075195,
#   'add': 5.8303117752075195,
#   'addition': 5.8303117752075195,
#   'addition to': 5.8303117752075195,
#   'adjustable': 5.424846649169922,
#   'adorable': 5.8303117752075195,
#   'after': 4.508555889129639,
#   'after you': 5.607168197631836,
#   'again': 5.607168197631836,
#   'age': 5.8303117752075195,
#   'air': 5.8303117752075195,
#   'all': 3.6056880950927734,
#   'all items': 5.607168197631836,
#   'all of': 5.8303117752075195,
#   'also': 4.383392810821533,
#   'also has': 5.8303117752075195,
#   'also have': 5.8303117752075195,
#   'always': 5.424846649169922,
#   'am': 5.019381523132324,
#   'am not': 5.8303117752075195,
#   'an': 5.019381523132324,
#   'and': 2.1167397499084473,
#   'and black': 5.8303117752075195,
#   'and body': 5.8303117752075195,
#   'and body works': 5.8303117752075195,
#   'and in': 5.8303117752075195,
#   'and is': 5.607168197631836,
#   'and one': 5.8303117752075195,
#   'and pet': 5.607168197631836,
#   'and pet free': 5.607168197631836,
#   'and the': 5.424846649169922,
#   'and they': 5.8303117752075195,
#   'and white': 5.424846649169922,
#   'and you': 5.8303117752075195,
#   'another': 5.607168197631836,
#   'any': 3.9585094451904297,
#   'any questions': 4.651656627655029,
#   'any questions please': 5.424846649169922,
#   'apple': 5.270695686340332,
#   'apple iphone': 5.8303117752075195,
#   'approximately': 5.424846649169922,
#   'aqua': 5.8303117752075195,
#   'are': 3.553044557571411,
#   'are not': 5.607168197631836,
#   'armour': 5.8303117752075195,
#   'around': 4.818710803985596,
#   'around the': 5.8303117752075195,
#   'as': 3.7200984954833984,
#   'as pictured': 5.607168197631836,
#   'as you': 5.8303117752075195,
#   'ask': 4.038552284240723,
#   'ask any': 5.8303117752075195,
#   'ask me': 5.8303117752075195,
#   'at': 4.326234340667725,
#   'at the': 5.019381523132324,
#   'authentic': 4.038552284240723,
#   'available': 5.13716459274292,
#   'baby': 5.424846649169922,
#   'back': 3.920769214630127,
#   'back and': 5.607168197631836,
#   'background': 5.13716459274292,
#   'background with': 5.424846649169922,
#   'bag': 5.019381523132324,
#   'banana': 5.607168197631836,
#   'banana republic': 5.8303117752075195,
#   'band': 5.424846649169922,
#   'barely': 5.8303117752075195,
#   'base': 5.8303117752075195,
#   'baseball': 5.8303117752075195,
#   'based': 5.8303117752075195,
#   'bath': 5.8303117752075195,
#   'bath and': 5.8303117752075195,
#   'bath and body': 5.8303117752075195,
#   'batman': 5.8303117752075195,
#   'batteries': 5.8303117752075195,
#   'be': 3.7200984954833984,
#   'be ignored': 5.8303117752075195,
#   'be used': 5.607168197631836,
#   'beautiful': 4.577548980712891,
#   'beauty': 5.270695686340332,
#   'because': 5.607168197631836,
#   'bed': 5.8303117752075195,
#   'been': 4.326234340667725,
#   'been used': 5.019381523132324,
#   'been worn': 5.8303117752075195,
#   'before': 4.577548980712891,
#   'before purchasing': 5.607168197631836,
#   'being': 5.8303117752075195,
#   'below': 5.8303117752075195,
#   'belt': 5.607168197631836,
#   'best': 5.424846649169922,
#   'better': 5.607168197631836,
#   'better than': 5.8303117752075195,
#   'big': 4.914021015167236,
#   'bio': 5.607168197631836,
#   'bit': 5.270695686340332,
#   'bit of': 5.607168197631836,
#   'black': 3.633087158203125,
#   'black with': 5.8303117752075195,
#   'bling': 5.8303117752075195,
#   'blue': 4.172083854675293,
#   'blue and': 5.424846649169922,
#   'blush': 5.8303117752075195,
#   'body': 5.13716459274292,
#   'body works': 5.8303117752075195,
#   'boot': 5.8303117752075195,
#   'boots': 5.270695686340332,
#   'both': 5.13716459274292,
#   'bottom': 5.019381523132324,
#   'bottom of': 5.8303117752075195,
#   'bottoms': 5.8303117752075195,
#   'bought': 5.13716459274292,
#   'boutique': 5.8303117752075195,
#   'bow': 5.8303117752075195,
#   'box': 3.4789364337921143,
#   'boy': 5.607168197631836,
#   'boys': 5.424846649169922,
#   'bra': 5.270695686340332,
#   'bracelet': 5.8303117752075195,
#   'brand': 2.8345794677734375,
#   'brand new': 2.9399399757385254,
#   'brand new and': 5.424846649169922,
#   'brand new in': 4.651656627655029,
#   'brand new never': 4.731699466705322,
#   'brand new with': 5.13716459274292,
#   'brandy': 5.424846649169922,
#   'brandy melville': 5.8303117752075195,
#   'brown': 4.914021015167236,
#   'brown leather': 5.8303117752075195,
#   'brush': 5.607168197631836,
#   'bundle': 4.038552284240723,
#   'bundle for': 5.270695686340332,
#   'bundle to': 5.13716459274292,
#   'bundle to save': 5.270695686340332,
#   'bundled': 5.8303117752075195,
#   'bundles': 5.13716459274292,
#   'bundling': 5.8303117752075195,
#   'burgundy': 5.607168197631836,
#   'business': 5.8303117752075195,
#   'but': 3.553044557571411,
#   'but has': 5.8303117752075195,
#   'but it': 5.8303117752075195,
#   'but not': 5.424846649169922,
#   'buy': 4.651656627655029,
#   'buying': 5.8303117752075195,
#   'by': 3.9585094451904297,
#   'cable': 5.8303117752075195,
#   'can': 3.884401559829712,
#   'can be': 4.651656627655029,
#   'can be used': 5.8303117752075195,
#   'candy': 5.607168197631836,
#   'care': 5.424846649169922,
#   'case': 5.13716459274292,
#   'cases': 5.8303117752075195,
#   'chain': 5.607168197631836,
#   'charged': 5.8303117752075195,
#   'charger': 5.13716459274292,
#   'check': 4.651656627655029,
#   'check out': 4.818710803985596,
#   'check out my': 4.914021015167236,
#   'chest': 5.8303117752075195,
#   'china': 5.607168197631836,
#   'chips': 5.8303117752075195,
#   'christmas': 5.424846649169922,
#   'classic': 5.8303117752075195,
#   'clean': 5.607168197631836,
#   'cleanser': 5.8303117752075195,
#   'closet': 4.914021015167236,
#   'closure': 5.607168197631836,
#   'clothes': 5.8303117752075195,
#   'cold': 5.8303117752075195,
#   'collection': 5.607168197631836,
#   'color': 3.6902456283569336,
#   'color black': 5.8303117752075195,
#   'color with': 5.8303117752075195,
#   'colored': 5.8303117752075195,
#   'colors': 4.731699466705322,
#   'combine': 5.8303117752075195,
#   'come': 5.019381523132324,
#   'come first': 5.8303117752075195,
#   'come first serve': 5.8303117752075195,
#   'comes': 4.172083854675293,
#   'comes with': 4.326234340667725,
#   'comfortable': 5.13716459274292,
#   'comfy': 5.607168197631836,
#   'comment': 5.270695686340332,
#   'compatible': 5.8303117752075195,
#   'complete': 5.8303117752075195,
#   'condition': 2.9261465072631836,
#   'condition and': 5.8303117752075195,
#   'condition minor': 5.8303117752075195,
#   'condition no': 5.270695686340332,
#   'condition no flaws': 5.8303117752075195,
#   'condition size': 5.8303117752075195,
#   'condition worn': 5.8303117752075195,
#   'conditions': 5.8303117752075195,
#   'contains': 5.8303117752075195,
#   'cool': 5.607168197631836,
#   'cord': 5.607168197631836,
#   'cosmetics': 5.8303117752075195,
#   'cotton': 5.270695686340332,
#   'could': 5.8303117752075195,
#   'cover': 5.607168197631836,
#   'cracks': 5.424846649169922,
#   'cracks or': 5.8303117752075195,
#   'cream': 4.914021015167236,
#   'creamy': 5.8303117752075195,
#   'create': 5.8303117752075195,
#   'crop': 5.424846649169922,
#   'cut': 5.8303117752075195,
#   'cute': 4.125563621520996,
#   'damage': 5.8303117752075195,
#   'dark': 4.818710803985596,
#   'dark brown': 5.8303117752075195,
#   'day': 4.326234340667725,
#   'days': 4.577548980712891,
#   'deal': 5.607168197631836,
#   'deep': 5.8303117752075195,
#   'description': 3.782618999481201,
#   'description yet': 3.815408706665039,
#   'design': 5.270695686340332,
#   'detail': 5.607168197631836,
#   'diamond': 5.8303117752075195,
#   'didn': 5.8303117752075195,
#   'different': 5.13716459274292,
#   'discount': 5.424846649169922,
#   'distressed': 5.424846649169922,
#   'do': 4.651656627655029,
#   'do not': 5.607168197631836,
#   'does': 5.019381523132324,
#   'does not': 5.607168197631836,
#   'doesn': 5.607168197631836,
#   'dog': 5.270695686340332,
#   'dollars': 5.8303117752075195,
#   'don': 4.326234340667725,
#   'don ask': 5.607168197631836,
#   'dot': 5.8303117752075195,
#   'double': 5.607168197631836,
#   'down': 5.607168197631836,
#   'dress': 4.651656627655029,
#   'dry': 5.424846649169922,
#   'due': 5.607168197631836,
#   'due to': 5.607168197631836,
#   'dunn': 5.8303117752075195,
#   'during': 5.8303117752075195,
#   'during the': 5.8303117752075195,
#   'dvd': 5.607168197631836,
#   'each': 4.383392810821533,
#   'easier': 5.8303117752075195,
#   'easily': 5.8303117752075195,
#   'easy': 5.019381523132324,
#   'easy to': 5.424846649169922,
#   'elastic': 5.8303117752075195,
#   'essential': 5.8303117752075195,
#   'etc': 5.019381523132324,
#   'even': 5.607168197631836,
#   'ever': 5.607168197631836,
#   'every': 5.8303117752075195,
#   'everything': 4.651656627655029,
#   'excellent': 4.914021015167236,
#   'excellent condition': 5.019381523132324,
#   'extra': 5.607168197631836,
#   'extremely': 5.8303117752075195,
#   'eye': 5.13716459274292,
#   'eyebrow': 5.8303117752075195,
#   'eyebrows': 5.8303117752075195,
#   'eyes': 5.8303117752075195,
#   'fabric': 5.607168197631836,
#   'faced': 5.8303117752075195,
#   'factory': 5.8303117752075195,
#   'factory sealed': 5.8303117752075195,
#   'fair': 5.8303117752075195,
#   'fall': 5.424846649169922,
#   'fast': 4.914021015167236,
#   'fast free': 5.607168197631836,
#   'fast free shipping': 5.607168197631836,
#   'faux': 5.8303117752075195,
#   'favorite': 5.607168197631836,
#   'features': 5.270695686340332,
#   'feedback': 5.8303117752075195,
#   'feel': 4.914021015167236,
#   'feel free': 5.13716459274292,
#   'feel free to': 5.13716459274292,
#   'few': 4.731699466705322,
#   'find': 4.818710803985596,
#   'firm': 3.997730255126953,
#   'first': 5.270695686340332,
#   'first come': 5.8303117752075195,
#   'first come first': 5.8303117752075195,
#   'first serve': 5.8303117752075195,
#   'fit': 4.383392810821533,
#   'fits': 4.383392810821533,
#   'fitted': 5.607168197631836,
#   'fl': 5.8303117752075195,
#   'fl oz': 5.8303117752075195,
#   'flat': 5.270695686340332,
#   'flaws': 4.731699466705322,
#   'floral': 5.607168197631836,
#   'flower': 5.607168197631836,
#   'flowers': 5.8303117752075195,
#   'follow': 5.8303117752075195,
#   'for': 2.4459214210510254,
#   'for all': 5.8303117752075195,
#   'for an': 5.8303117752075195,
#   'for any': 5.8303117752075195,
#   'for apple': 5.8303117752075195,
#   'for apple iphone': 5.8303117752075195,
#   'for each': 5.607168197631836,
#   'for few': 5.8303117752075195,
#   'for free': 5.8303117752075195,
#   'for free shipping': 5.8303117752075195,
#   'for looking': 5.424846649169922,
#   'for more': 5.8303117752075195,
#   'for my': 5.270695686340332,
#   'for sale': 5.8303117752075195,
#   'for spring': 5.8303117752075195,
#   'for the': 5.270695686340332,
#   'for you': 5.424846649169922,
#   'forever': 5.607168197631836,
#   'four': 5.8303117752075195,
#   'free': 3.0894718170166016,
#   'free home': 4.508555889129639,
#   'free pet': 5.8303117752075195,
#   'free shipping': 3.782618999481201,
#   'free to': 5.13716459274292,
#   'free to ask': 5.607168197631836,
#   'fresh': 5.607168197631836,
#   'friendly': 5.8303117752075195,
#   'friendly home': 5.8303117752075195,
#   'from': 3.4554059505462646,
#   'from my': 5.424846649169922,
#   'from my closet': 5.8303117752075195,
#   'from smoke': 5.270695686340332,
#   'from smoke free': 5.424846649169922,
#   'from victoria': 5.607168197631836,
#   'from victoria secret': 5.607168197631836,
#   'front': 4.914021015167236,
#   'ft': 5.8303117752075195,
#   'full': 4.914021015167236,
#   'full size': 5.607168197631836,
#   'fun': 5.8303117752075195,
#   'games': 5.424846649169922,
#   'gently': 5.270695686340332,
#   'gently used': 5.8303117752075195,
#   'get': 4.818710803985596,
#   'getting': 5.8303117752075195,
#   'gift': 5.270695686340332,
#   'girl': 5.019381523132324,
#   'girls': 5.607168197631836,
#   'glitter': 5.424846649169922,
#   'gold': 4.731699466705322,
#   'good': 3.920769214630127,
#   'good condition': 4.44401741027832,
#   'good used': 5.8303117752075195,
#   'good used condition': 5.8303117752075195,
#   'gorgeous': 5.424846649169922,
#   'got': 5.607168197631836,
#   'gray': 5.13716459274292,
#   'great': 3.284780502319336,
#   'great condition': 4.125563621520996,
#   'great condition no': 5.607168197631836,
#   'great for': 5.270695686340332,
#   'great shape': 5.8303117752075195,
#   'green': 5.019381523132324,
#   'grey': 5.8303117752075195,
#   'guaranteed': 5.8303117752075195,
#   'had': 5.8303117752075195,
#   'halloween': 5.607168197631836,
#   'hand': 5.424846649169922,
#   'hands': 5.8303117752075195,
#   'happy': 5.8303117752075195,
#   'hard': 5.424846649169922,
#   'hard to': 5.8303117752075195,
#   'hard to find': 5.8303117752075195,
#   'hardware': 5.8303117752075195,
#   'has': 3.8493101596832275,
#   'has pockets': 5.8303117752075195,
#   'have': 3.3879647254943848,
#   'have any': 5.270695686340332,
#   'have any questions': 5.424846649169922,
#   'have been': 5.8303117752075195,
#   'have the': 5.13716459274292,
#   'he': 5.8303117752075195,
#   'head': 5.8303117752075195,
#   'heel': 5.607168197631836,
#   'hello': 5.424846649169922,
#   'hello kitty': 5.424846649169922,
#   'help': 5.8303117752075195,
#   'here': 5.607168197631836,
#   'high': 4.44401741027832,
#   'high quality': 5.424846649169922,
#   'highly': 5.424846649169922,
#   'his': 5.607168197631836,
#   'hold': 5.607168197631836,
#   'holds': 5.13716459274292,
#   'holes': 5.13716459274292,
#   'home': 4.172083854675293,
#   'hoodie': 5.607168197631836,
#   'hot': 5.424846649169922,
#   'hours': 5.270695686340332,
#   'how': 5.424846649169922,
#   'if': 3.815408706665039,
#   'if you': 4.272167205810547,
#   'if you are': 5.8303117752075195,
#   'if you have': 5.13716459274292,
#   'if you want': 5.8303117752075195,
#   'ignored': 5.8303117752075195,
#   'in': 2.311331272125244,
#   'in box': 4.651656627655029,
#   'in china': 5.8303117752075195,
#   'in days': 5.8303117752075195,
#   'in good': 5.13716459274292,
#   'in good condition': 5.270695686340332,
#   'in great': 5.019381523132324,
#   'in great condition': 5.424846649169922,
#   'in my': 5.8303117752075195,
#   'in one': 5.8303117752075195,
#   'in package': 5.607168197631836,
#   'in perfect': 5.13716459274292,
#   'in perfect condition': 5.270695686340332,
#   'in the': 4.172083854675293,
#   'in the back': 5.8303117752075195,
#   'in your': 5.270695686340332,
#   'inches': 5.607168197631836,
#   'include': 5.607168197631836,
#   'included': 4.818710803985596,
#   'includes': 4.818710803985596,
#   'inseam': 5.8303117752075195,
#   'inside': 5.270695686340332,
#   'instant': 5.607168197631836,
#   'ipad': 5.8303117752075195,
#   'iphone': 4.914021015167236,
#   'iphone 5c': 5.607168197631836,
#   'iphone plus': 5.607168197631836,
#   'is': 2.7279696464538574,
#   'is firm': 4.577548980712891,
#   'is in': 5.13716459274292,
#   'is my': 5.8303117752075195,
#   'is new': 5.8303117752075195,
#   'is not': 5.607168197631836,
#   'is so': 5.8303117752075195,
#   'issues': 5.8303117752075195,
#   'it': 3.3045830726623535,
#   'it also': 5.607168197631836,
#   'it is': 4.44401741027832,
#   'it was': 5.8303117752075195,
#   'it will': 5.8303117752075195,
#   'item': 3.997730255126953,
#   'item is': 5.424846649169922,
#   'items': 4.125563621520996,
#   'items in': 5.8303117752075195,
#   'its': 5.607168197631836,
#   'jacket': 5.270695686340332,
#   'jeans': 5.424846649169922,
#   'jenner': 5.8303117752075195,
#   'jordan': 5.8303117752075195,
#   'just': 4.125563621520996,
#   'kawaii': 5.8303117752075195,
#   'key': 5.607168197631836,
#   'kids': 5.607168197631836,
#   'kit': 5.607168197631836,
#   'kitty': 5.270695686340332,
#   'know': 5.607168197631836,
#   'know if': 5.8303117752075195,
#   'kylie': 5.424846649169922,
#   'kylie jenner': 5.8303117752075195,
#   'lace': 5.607168197631836,
#   'large': 4.272167205810547,
#   'lash': 5.8303117752075195,
#   'lashes': 5.607168197631836,
#   'last': 5.424846649169922,
#   'leather': 4.44401741027832,
#   'left': 5.13716459274292,
#   'leg': 5.607168197631836,
#   'leggings': 4.731699466705322,
#   'length': 4.577548980712891,
#   'let': 5.8303117752075195,
#   'let me': 5.8303117752075195,
#   'let me know': 5.8303117752075195,
#   'life': 5.424846649169922,
#   'life left': 5.8303117752075195,
#   'light': 4.383392810821533,
#   'light blue': 5.8303117752075195,
#   'light pink': 5.424846649169922,
#   'lightly': 5.8303117752075195,
#   'like': 3.6612579822540283,
#   'like new': 4.508555889129639,
#   'line': 5.8303117752075195,
#   'lined': 5.607168197631836,
#   'liner': 5.8303117752075195,
#   'lip': 4.651656627655029,
#   'lipstick': 5.13716459274292,
#   'liquid': 4.818710803985596,
#   'liquid lipstick': 5.607168197631836,
#   'listed': 5.607168197631836,
#   'listing': 5.607168197631836,
#   'listings': 4.914021015167236,
#   'listings for': 5.8303117752075195,
#   'little': 4.577548980712891,
#   'll': 5.607168197631836,
#   'logo': 5.13716459274292,
#   'long': 4.326234340667725,
#   'longer': 5.8303117752075195,
#   'look': 5.13716459274292,
#   'looking': 5.13716459274292,
#   'looks': 5.424846649169922,
#   'looks like': 5.8303117752075195,
#   'loose': 5.607168197631836,
#   'lot': 5.270695686340332,
#   'lots': 5.13716459274292,
#   'lots of': 5.424846649169922,
#   'love': 5.13716459274292,
#   'lower': 5.8303117752075195,
#   'lowest': 5.8303117752075195,
#   'lularoe': 5.424846649169922,
#   'lululemon': 5.607168197631836,
#   'made': 4.508555889129639,
#   'made in': 5.13716459274292,
#   'made in china': 5.8303117752075195,
#   'made of': 5.607168197631836,
#   'mail': 5.8303117752075195,
#   'make': 5.019381523132324,
#   'makeup': 5.607168197631836,
#   'making': 5.8303117752075195,
#   'many': 5.8303117752075195,
#   'mark': 5.607168197631836,
#   'mark on': 5.8303117752075195,
#   'mascara': 5.607168197631836,
#   'matching': 5.424846649169922,
#   'material': 4.914021015167236,
#   'maternity': 5.8303117752075195,
#   'matte': 5.13716459274292,
#   'matte lip': 5.8303117752075195,
#   'may': 5.019381523132324,
#   'maybelline': 5.607168197631836,
#   'me': 4.172083854675293,
#   'me for': 5.8303117752075195,
#   'me know': 5.8303117752075195,
#   'me know if': 5.8303117752075195,
#   'measurements': 5.8303117752075195,
#   'med': 5.8303117752075195,
#   'medium': 3.884401559829712,
#   'medium large': 5.8303117752075195,
#   'melville': 5.607168197631836,
#   'men': 5.270695686340332,
#   'message': 5.270695686340332,
#   'message me': 5.424846649169922,
#   'mini': 5.13716459274292,
#   'minor': 4.914021015167236,
#   'miss': 5.8303117752075195,
#   'missing': 5.424846649169922,
#   'money': 5.8303117752075195,
#   'more': 4.220873832702637,
#   'most': 5.424846649169922,
#   'much': 5.8303117752075195,
#   'multi': 5.8303117752075195,
#   'multiple': 5.8303117752075195,
#   'my': 3.4324164390563965,
#   'my closet': 5.270695686340332,
#   'my listings': 5.8303117752075195,
#   'my other': 5.270695686340332,
#   'my other listings': 5.8303117752075195,
#   'name': 5.8303117752075195,
#   'natural': 5.270695686340332,
#   'natural and': 5.8303117752075195,
#   'navy': 5.270695686340332,
#   'navy blue': 5.424846649169922,
#   'neck': 5.8303117752075195,
#   'necklace': 5.019381523132324,
#   'need': 5.607168197631836,
#   'never': 3.1735548973083496,
#   'never been': 4.818710803985596,
#   'never been used': 5.424846649169922,
#   'never opened': 5.424846649169922,
#   'never used': 4.326234340667725,
#   'never worn': 4.125563621520996,
#   'never worn size': 5.8303117752075195,
#   'new': 2.166749954223633,
#   'new and': 4.818710803985596,
#   'new condition': 5.8303117752075195,
#   'new in': 4.326234340667725,
#   'new in box': 4.731699466705322,
#   'new in package': 5.8303117752075195,
#   'new never': 4.383392810821533,
#   'new never used': 5.270695686340332,
#   'new never worn': 5.13716459274292,
#   'new still': 5.8303117752075195,
#   'new with': 4.081111907958984,
#   'new with tag': 5.607168197631836,
#   'new with tags': 4.577548980712891,
#   'new without': 5.607168197631836,
#   'new york': 5.8303117752075195,
#   'next': 5.8303117752075195,
#   'nib': 5.8303117752075195,
#   'nike': 5.607168197631836,
#   'no': 2.7857894897460938,
#   'no box': 5.424846649169922,
#   'no description': 3.815408706665039,
#   'no description yet': 3.815408706665039,
#   'no flaws': 5.019381523132324,
#   'no free': 5.607168197631836,
#   'no free shipping': 5.607168197631836,
#   'no holds': 5.8303117752075195,
#   'no holes': 5.8303117752075195,
#   'no stains': 5.270695686340332,
#   'no trades': 5.8303117752075195,
#   'normal': 5.8303117752075195,
#   'not': 3.4789364337921143,
#   'not included': 5.8303117752075195,
#   'not noticeable': 5.8303117752075195,
#   'not responsible': 5.8303117752075195,
#   'not responsible for': 5.8303117752075195,
#   'noticeable': 5.270695686340332,
#   'now': 5.607168197631836,
#   'nude': 5.8303117752075195,
#   'number': 5.8303117752075195,
#   'nwot': 5.607168197631836,
#   'nwt': 4.731699466705322,
#   'nyx': 5.607168197631836,
#   'of': 2.7977654933929443,
#   'of life': 5.607168197631836,
#   'of life left': 5.8303117752075195,
#   'of my': 4.914021015167236,
#   'of the': 4.44401741027832,
#   'of wear': 5.8303117752075195,
#   'off': 4.577548980712891,
#   'offers': 5.270695686340332,
#   'offers will': 5.8303117752075195,
#   'offers will be': 5.8303117752075195,
#   'office': 5.270695686340332,
#   'old': 5.8303117752075195,
#   'on': 2.912540912628174,
#   'on back': 5.270695686340332,
#   'on front': 5.607168197631836,
#   'on me': 5.8303117752075195,
#   'on one': 5.8303117752075195,
#   'on shipping': 5.270695686340332,
#   'on the': 4.508555889129639,
#   'on the front': 5.8303117752075195,
#   'on your': 5.8303117752075195,
#   'once': 4.326234340667725,
#   'one': 3.553044557571411,
#   'one size': 5.019381523132324,
#   'one size fits': 5.607168197631836,
#   'one time': 5.8303117752075195,
#   'only': 4.172083854675293,
#   'only worn': 5.8303117752075195,
#   'only worn once': 5.8303117752075195,
#   'opened': 4.914021015167236,
#   'or': 3.246314287185669,
#   'orange': 5.8303117752075195,
#   'order': 5.424846649169922,
#   'original': 4.651656627655029,
#   'original box': 5.424846649169922,
#   'os': 5.8303117752075195,
#   'other': 4.326234340667725,
#   'other items': 5.424846649169922,
#   'other listings': 5.8303117752075195,
#   'otherwise': 5.8303117752075195,
#   'our': 5.607168197631836,
#   'out': 3.815408706665039,
#   'out my': 4.914021015167236,
#   'out my closet': 5.8303117752075195,
#   'out my other': 5.607168197631836,
#   'out of': 5.270695686340332,
#   'over': 5.8303117752075195,
#   'overall': 5.8303117752075195,
#   'oz': 4.508555889129639,
#   'pack': 5.019381523132324,
#   'package': 4.577548980712891,
#   'packaging': 5.424846649169922,
#   'page': 5.607168197631836,
#   'paid': 5.607168197631836,
#   'pair': 5.270695686340332,
#   'pairs': 5.607168197631836,
#   'palette': 5.8303117752075195,
#   'pants': 4.914021015167236,
#   'part': 5.607168197631836,
#   'part of': 5.607168197631836,
#   'pattern': 5.607168197631836,
#   'pay': 5.8303117752075195,
#   'pay shipping': 5.8303117752075195,
#   'pearl': 5.8303117752075195,
#   'people': 5.8303117752075195,
#   'per': 5.8303117752075195,
#   'perfect': 3.8493101596832275,
#   'perfect condition': 4.818710803985596,
#   'perfect for': 5.13716459274292,
#   'perfect for spring': 5.8303117752075195,
#   'perfectly': 5.8303117752075195,
#   'pet': 4.914021015167236,
#   'pet free': 5.13716459274292,
#   'pet free home': 5.270695686340332,
#   'phone': 5.424846649169922,
#   'photo': 5.8303117752075195,
#   'photos': 5.424846649169922,
#   'pic': 5.270695686340332,
#   'pics': 5.607168197631836,
#   'picture': 4.651656627655029,
#   'picture is': 5.8303117752075195,
#   'pictured': 5.270695686340332,
#   'pictures': 4.731699466705322,
#   'pilling': 5.607168197631836,
#   'pink': 3.6902456283569336,
#   'pink logo': 5.8303117752075195,
#   'plastic': 5.8303117752075195,
#   'please': 3.6056880950927734,
#   'please ask': 4.914021015167236,
#   'please don': 5.424846649169922,
#   'please read': 5.8303117752075195,
#   'please see': 5.270695686340332,
#   'plus': 4.731699466705322,
#   'pocket': 5.13716459274292,
#   'pockets': 5.607168197631836,
#   'polka': 5.424846649169922,
#   'polka dot': 5.8303117752075195,
#   'polyester': 5.13716459274292,
#   'pop': 5.607168197631836,
#   'post': 5.019381523132324,
#   'post office': 5.607168197631836,
#   'powder': 5.607168197631836,
#   'present': 5.607168197631836,
#   'pretty': 5.607168197631836,
#   'price': 3.5030341148376465,
#   'price firm': 5.424846649169922,
#   'price is': 4.272167205810547,
#   'price is firm': 4.651656627655029,
#   'prices': 5.607168197631836,
#   'print': 4.914021015167236,
#   'priority': 5.424846649169922,
#   'pro': 5.8303117752075195,
#   'product': 5.270695686340332,
#   'profile': 5.8303117752075195,
#   'protection': 5.424846649169922,
#   'provide': 5.8303117752075195,
#   'pull': 5.8303117752075195,
#   'pumpkin': 5.8303117752075195,
#   'purchase': 4.577548980712891,
#   'purchased': 5.270695686340332,
#   'purchasing': 5.270695686340332,
#   'purple': 4.914021015167236,
#   'purse': 5.607168197631836,
#   'quality': 5.019381523132324,
#   'question': 5.8303117752075195,
#   'questions': 4.383392810821533,
#   'questions please': 5.424846649169922,
#   'questions please ask': 5.607168197631836,
#   'quickly': 5.607168197631836,
#   'rae': 5.8303117752075195,
#   'rae dunn': 5.8303117752075195,
#   'rarely': 5.8303117752075195,
#   'rate': 5.607168197631836,
#   're': 5.8303117752075195,
#   'read': 5.270695686340332,
#   'read my': 5.8303117752075195,
#   'ready': 5.8303117752075195,
#   'real': 5.607168197631836,
#   'receive': 5.270695686340332,
#   'red': 4.326234340667725,
#   'reflect': 5.8303117752075195,
#   'regular': 5.607168197631836,
#   'republic': 5.8303117752075195,
#   'responsible': 5.8303117752075195,
#   'responsible for': 5.8303117752075195,
#   'retail': 5.019381523132324,
#   'retails': 5.424846649169922,
#   'retails for': 5.8303117752075195,
#   'return': 5.607168197631836,
#   'right': 5.8303117752075195,
#   'ring': 5.8303117752075195,
#   'rips': 5.8303117752075195,
#   'rise': 5.8303117752075195,
#   'room': 5.424846649169922,
#   'rose': 5.8303117752075195,
#   'royal': 5.8303117752075195,
#   'run': 5.8303117752075195,
#   'runs': 5.8303117752075195,
#   'safe': 5.270695686340332,
#   'sale': 5.424846649169922,
#   'same': 4.731699466705322,
#   'same day': 5.13716459274292,
#   'sample': 5.8303117752075195,
#   'save': 4.577548980712891,
#   'save on': 5.424846649169922,
#   'save on shipping': 5.424846649169922,
#   'scent': 5.607168197631836,
#   'scratches': 5.607168197631836,
#   'screen': 5.424846649169922,
#   'seal': 5.8303117752075195,
#   'sealed': 5.13716459274292,
#   'secret': 4.326234340667725,
#   'secret pink': 4.914021015167236,
#   'see': 4.651656627655029,
#   'sell': 5.270695686340332,
#   'seller': 5.8303117752075195,
#   'selling': 4.818710803985596,
#   'selling this': 5.8303117752075195,
#   'sent': 5.607168197631836,
#   'separately': 5.8303117752075195,
#   'serum': 5.607168197631836,
#   'serve': 5.8303117752075195,
#   'set': 4.651656627655029,
#   'set of': 5.8303117752075195,
#   'sets': 5.8303117752075195,
#   'shade': 5.607168197631836,
#   'shades': 5.8303117752075195,
#   'shape': 5.13716459274292,
#   'sheer': 5.8303117752075195,
#   'shield': 5.8303117752075195,
#   'ship': 3.997730255126953,
#   'ship the': 5.8303117752075195,
#   'ship within': 5.8303117752075195,
#   'shipped': 4.818710803985596,
#   'shipping': 3.2276220321655273,
#   'shipping price': 5.8303117752075195,
#   'shipping price is': 5.8303117752075195,
#   'shipping you': 5.8303117752075195,
#   'ships': 5.13716459274292,
#   'shirt': 4.731699466705322,
#   'shoe': 5.8303117752075195,
#   'shoes': 5.13716459274292,
#   'shorts': 5.270695686340332,
#   'should': 5.8303117752075195,
#   'shoulder': 5.424846649169922,
#   'show': 5.8303117752075195,
#   'shown': 5.270695686340332,
#   'shown in': 5.424846649169922,
#   'shows': 5.8303117752075195,
#   'side': 5.607168197631836,
#   'sides': 5.607168197631836,
#   'signature': 5.424846649169922,
#   'signs': 5.8303117752075195,
#   'signs of': 5.8303117752075195,
#   'silver': 5.270695686340332,
#   'size': 2.3567936420440674,
#   'size 10': 5.424846649169922,
#   'size 11': 5.607168197631836,
#   'size fits': 5.607168197631836,
#   'size large': 4.914021015167236,
#   'size med': 5.8303117752075195,
#   'size medium': 4.731699466705322,
#   'size small': 4.326234340667725,
#   'size small but': 5.8303117752075195,
#   'size xs': 5.424846649169922,
#   'sized': 5.8303117752075195,
#   'sizes': 5.270695686340332,
#   'skin': 5.270695686340332,
#   'skinny': 5.8303117752075195,
#   'skirt': 5.8303117752075195,
#   'sleep': 5.8303117752075195,
#   'sleeve': 5.607168197631836,
#   'sleeved': 5.8303117752075195,
#   'sleeves': 5.607168197631836,
#   'slightly': 5.607168197631836,
#   'slime': 5.8303117752075195,
#   'slot': 5.8303117752075195,
#   'small': 3.782618999481201,
#   'small but': 5.8303117752075195,
#   'smoke': 4.220873832702637,
#   'smoke and': 5.424846649169922,
#   'smoke and pet': 5.607168197631836,
#   'smoke free': 4.577548980712891,
#   'smoke free home': 5.13716459274292,
#   'smoke free pet': 5.8303117752075195,
#   'so': 4.125563621520996,
#   'so please': 5.607168197631836,
#   'socks': 5.607168197631836,
#   'soft': 4.383392810821533,
#   'sold': 5.13716459274292,
#   'some': 4.818710803985596,
#   'someone': 5.8303117752075195,
#   'spandex': 5.8303117752075195,
#   'special': 5.8303117752075195,
#   'spring': 5.8303117752075195,
#   'stains': 5.019381523132324,
#   'stains or': 5.8303117752075195,
#   'stand': 5.607168197631836,
#   'star': 5.8303117752075195,
#   'sticker': 5.8303117752075195,
#   'stickers': 5.8303117752075195,
#   'still': 4.577548980712891,
#   'still in': 5.8303117752075195,
#   'stones': 5.8303117752075195,
#   'storage': 5.8303117752075195,
#   'store': 5.8303117752075195,
#   'strap': 5.019381523132324,
#   'straps': 5.270695686340332,
#   'stretchy': 5.607168197631836,
#   'stripes': 5.8303117752075195,
#   'style': 4.818710803985596,
#   'such': 5.607168197631836,
#   'suede': 5.8303117752075195,
#   'suit': 5.424846649169922,
#   'summer': 5.607168197631836,
#   'super': 4.038552284240723,
#   'super cute': 4.731699466705322,
#   'super soft': 5.424846649169922,
#   'superman': 5.8303117752075195,
#   'sure': 5.8303117752075195,
#   'sweater': 5.8303117752075195,
#   'sweet': 5.607168197631836,
#   'sz': 5.8303117752075195,
#   'tag': 4.651656627655029,
#   'tags': 3.920769214630127,
#   'tags size': 5.8303117752075195,
#   'take': 4.818710803985596,
#   'taken': 5.270695686340332,
#   'takes': 5.424846649169922,
#   'tall': 5.13716459274292,
#   'tall and': 5.607168197631836,
#   'tan': 5.607168197631836,
#   'tank': 5.270695686340332,
#   'tank top': 5.607168197631836,
#   'tears': 5.607168197631836,
#   'tee': 5.8303117752075195,
#   'than': 4.731699466705322,
#   'thank': 5.019381523132324,
#   'thank you': 5.424846649169922,
#   'thanks': 4.818710803985596,
#   'thanks for': 5.270695686340332,
#   'thanks for looking': 5.607168197631836,
#   'that': 4.125563621520996,
#   'the': 2.489218235015869,
#   'the back': 5.019381523132324,
#   'the box': 5.8303117752075195,
#   'the front': 5.8303117752075195,
#   'the item': 5.607168197631836,
#   'the original': 5.8303117752075195,
#   'the picture': 5.8303117752075195,
#   'the price': 5.8303117752075195,
#   'the same': 5.13716459274292,
#   'the same day': 5.607168197631836,
#   'the size': 5.8303117752075195,
#   'the top': 5.424846649169922,
#   'their': 5.424846649169922,
#   'them': 4.651656627655029,
#   'then': 5.8303117752075195,
#   'there': 4.914021015167236,
#   'there are': 5.607168197631836,
#   'these': 4.272167205810547,
#   'these are': 5.270695686340332,
#   'they': 4.577548980712891,
#   'they are': 5.424846649169922,
#   'thick': 5.270695686340332,
#   'things': 5.8303117752075195,
#   'this': 3.3879647254943848,
#   'this is': 4.577548980712891,
#   'this item': 5.424846649169922,
#   'those': 5.8303117752075195,
#   'three': 5.424846649169922,
#   'through': 5.607168197631836,
#   'throw': 5.8303117752075195,
#   'ties': 5.607168197631836,
#   'time': 4.731699466705322,
#   'times': 4.914021015167236,
#   'tiny': 5.424846649169922,
#   'to': 2.7279696464538574,
#   'to any': 5.8303117752075195,
#   'to ask': 5.607168197631836,
#   'to find': 5.270695686340332,
#   'to rate': 5.8303117752075195,
#   'to save': 4.818710803985596,
#   'to save on': 5.424846649169922,
#   'to take': 5.8303117752075195,
#   'to the': 5.13716459274292,
#   'to use': 5.607168197631836,
#   'tone': 5.8303117752075195,
#   'too': 4.577548980712891,
#   'too big': 5.8303117752075195,
#   'too faced': 5.8303117752075195,
#   'top': 3.8493101596832275,
#   'top and': 5.8303117752075195,
#   'top with': 5.607168197631836,
#   'total': 5.607168197631836,
#   ...}}

# %% [markdown]
# words or phrase with top 100 tf-idf score

# %%
top_n_tfidf = tfidf_df.sort_values(by=["description_text_tfidf"], ascending=False).head(100)
top_n_tfidf
# Out:
#              description_text_tfidf
# slime                      5.830312
# wearing                    5.830312
# grey                       5.830312
# great shape                5.830312
# please read                5.830312
# ...                             ...
# for apple                  5.830312
# for any                    5.830312
# for an                     5.830312
# for all                    5.830312
# follow                     5.830312
#
# [100 rows x 1 columns]

# %%
top_n_tfidf.index
# Out:
# Index(['slime', 'wearing', 'grey', 'great shape', 'please read', 'understand',
#        'good used condition', 'good used', 'unique', 'polka dot', 'getting',
#        'gently used', 'fun', 'update', 'ft', 'store', 'from my closet',
#        'storage', 'friendly home', 'friendly', 'stones', 'used no', 'free pet',
#        'used to', 'four', 'pro', 'profile', 'for spring', 'for sale',
#        'guaranteed', 'had', 'hands', 'help', 'in days', 'in china', 'tried',
#        'trim', 'ignored', 'if you want', 'superman', 'if you are',
#        'perfect for spring', 'perfectly', 'photo', 'ultra', 'picture is',
#        'happy', 'suede', 'head', 'he', 'have been', 'pink logo', 'plastic',
#        'has pockets', 'under armour', 'hardware', 'hard to find', 'hard to',
#        'stripes', 'for more', 'provide', 'for free shipping', 'during',
#        'rarely', 'extremely', 're', 'every', 'read my', 'essential', 'elastic',
#        'ready', 'easily', 'easier', 'star', 'during the', 'dunn', 'eyebrows',
#        'reflect', 'wash', 'dot', 'dollars', 'republic', 'responsible', 'watch',
#        'responsible for', 'retails for', 'didn', 'diamond', 'right', 'eyebrow',
#        'eyes', 'for free', 'via usps', 'for few', 'for apple iphone',
#        'for apple', 'for any', 'for an', 'for all', 'follow'],
#       dtype='object')

# %%
# %%time
def text_data_tfidf_fe(data):
    top_tfidf_word = []
    top_tfidf_value = []
    for i in range(len(list(data["item_description"].values))):
        match = next((word for word in top_n_tfidf.index if word in data["item_description"][i]), False)
        if match != False:
            chosen_word = match
            chosen_tfidf = float(top_n_tfidf.loc[match])
            #print(chosen_word, chosen_tfidf)
            top_tfidf_word.insert(i, chosen_word)
            top_tfidf_value.insert(i, chosen_tfidf)
            #break
        else:
            chosen_word = "None"
            chosen_tfidf = 0.0
            top_tfidf_word.insert(i, chosen_word)
            top_tfidf_value.insert(i, chosen_tfidf)
            continue
    data["top_tfidf_word"] = top_tfidf_word
    data["top_tfidf_value"] = top_tfidf_value
    return data[["top_tfidf_word", "top_tfidf_value"]].head()

text_data_tfidf_fe(train_df)
text_data_tfidf_fe(test_df)
# Out:
# CPU times: user 770 ms, sys: 6.42 ms, total: 776 ms
# Wall time: 780 ms
#   top_tfidf_word  top_tfidf_value
# 0           None         0.000000
# 1             ft         5.830312
# 2           None         0.000000
# 3             he         5.830312
# 4             ft         5.830312

# %% [markdown]
# view the data again

# %%
train_df.head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name     price  \
# 0                                  Men/Tops/T-shirts    NoBrand 10.000000
# 1  Electronics/Computers & Tablets/Components & P...      Razer 52.000000
# 2                        Women/Tops & Blouses/Blouse     Target 10.000000
# 3                 Home/Home Décor/Home Décor Accents    NoBrand 35.000000
# 4                            Women/Jewelry/Necklaces    NoBrand 44.000000
#
#    shipping                                   item_description  \
# 0         1                                 No description yet
# 1         0  This keyboard is in great condition and works ...
# 2         1  Adorable top with a hint of lace and a key hol...
# 3         1  New with tags. Leather horses. Retail for [rm]...
# 4         0          Complete with certificate of authenticity
#
#   general_category        subcategory_1       subcategory_2  char_count  \
# 0              Men                 Tops            T-shirts          18
# 1      Electronics  Computers & Tablets  Components & Parts         188
# 2            Women       Tops & Blouses              Blouse         124
# 3             Home           Home Décor  Home Décor Accents         173
# 4            Women              Jewelry           Necklaces          41
#
#    word_count  word_density top_tfidf_word  top_tfidf_value
# 0           3      4.500000           None         0.000000
# 1          36      5.081081      perfectly         5.830312
# 2          29      4.133333             he         5.830312
# 3          32      5.242424        storage         5.830312
# 4           5      6.833333             he         5.830312

# %%
test_df.head()
# Out:
#    test_id                                      name  item_condition_id  \
# 0        0  Breast cancer "I fight like a girl" ring                  1
# 1        1  25 pcs NEW 7.5"x12" Kraft Bubble Mailers                  1
# 2        2                                 Coach bag                  1
# 3        3                             Floral Kimono                  2
# 4        4                          Life after Death                  3
#
#                                     category_name brand_name  shipping  \
# 0                             Women/Jewelry/Rings    NoBrand         1
# 1         Other/Office supplies/Shipping Supplies    NoBrand         1
# 2  Vintage & Collectibles/Bags and Purses/Handbag      Coach         1
# 3                         Women/Sweaters/Cardigan    NoBrand         0
# 4             Other/Books/Religion & Spirituality    NoBrand         1
#
#                                     item_description        general_category  \
# 0                                             Size 7                   Women
# 1  25 pcs NEW 7.5"x12" Kraft Bubble Mailers Lined...                   Other
# 2  Brand new coach bag. Bought for [rm] at a Coac...  Vintage & Collectibles
# 3  -floral kimono -never worn -lightweight and pe...                   Women
# 4  Rediscovering life after the loss of a loved o...                   Other
#
#      subcategory_1            subcategory_2  char_count  word_count  \
# 0          Jewelry                    Rings           6           2
# 1  Office supplies        Shipping Supplies         251          38
# 2  Bags and Purses                  Handbag          55          11
# 3         Sweaters                 Cardigan          67          10
# 4            Books  Religion & Spirituality         167          29
#
#    word_density top_tfidf_word  top_tfidf_value
# 0      2.000000           None         0.000000
# 1      6.435897             ft         5.830312
# 2      4.583333           None         0.000000
# 3      6.090909             he         5.830312
# 4      5.566667             ft         5.830312

# %% [markdown]
# checking the shape again

# %%
print('Train shape: {}\nTest shape: {}'.format(train_df.shape, test_df.shape))
# Out:
# Train shape: (500, 16)
# Test shape: (500, 15)

# %% [markdown]
# # Output Data
# output data as csv

# %%
train_df.to_csv("train_df.csv", index=False)
test_df.to_csv("test_df.csv", index=False)
